# %%
import pandas as pd
from kiwipiepy import Kiwi
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer

# %%
df = pd.read_excel("total_25_final.xlsx")
df.shape
# Out:
# (84102, 15)

# %%
class Seperate:
    def __init__(self, df):
        self.df = df
     
    def this_month(self):
        return self.df[self.df.time.str.contains("초|분|시간|일")].reset_index(drop=True)

# %% [markdown]
# # BPE 단어학습

# %%
# a = Seperate(df)
# this_month = a.this_month()
# this_month.shape

# %%
# 일년 내 자료로 title 단어 학습 

with open ('sample_year.txt', 'w', encoding='utf8') as f:
    for row in df.itertuples():
        f.write(row.title)
        f.write('\n')
        
from tokenizers import CharBPETokenizer
bpe = CharBPETokenizer(lowercase=True)
bpe.train(files='sample_year.txt', min_frequency=30, vocab_size=50000)

# %% [markdown]
# ## 토큰화 결과 비교

# %%
# BPE를 활용한 토크나이저 함수 
# 길이가 1 이상인 것만 추출 
def tokenizer(text):
    enc = bpe.encode(text)
    for token in enc.tokens:
        token = token.replace('</w>', '')
        if len(token) > 1:
            yield token

# 키위 토크나이저 
kiwi = Kiwi()
def extract_noun(text):
    result = kiwi.analyze(text)
    for lemma, pos, _, _ in result[0][0]:
        if pos.startswith('N'):
            yield lemma
            
def compare(num):
    text = df.title[num]
    print('article title:' , text)
    print('-'*60)
    print('bpe tokenizer:', list(tokenizer(text)))
    print('kiwi tokenizer:', list(extract_noun(text)))

# %%
for i in range(1650,1850):
    compare(i)

# 청정원이 잘 추출됨
# Out:
# article title: 더바디샵 모링가 세트
# ------------------------------------------------------------
# bpe tokenizer: ['더바디샵', '모링가', '세트']
# kiwi tokenizer: ['더바디샵', '모링', '가', '세트']
# article title: 마스터 3종 세트
# ------------------------------------------------------------
# bpe tokenizer: ['마스터', '3종', '세트']
# kiwi tokenizer: ['마스터', '종', '세트']
# article title: 폴란드 볼레스와비예츠 찻잔 2개세트 미사용
# ------------------------------------------------------------
# bpe tokenizer: ['폴란드', '스와', '찻잔', '2개세트', '미사용']
# kiwi tokenizer: ['폴란드', '볼레스와비예츠', '찻잔', '개', '세트', '미사']
# article title: 록시땅 핸드크림
# ------------------------------------------------------------
# bpe tokenizer: ['록시땅', '핸드크림']
# kiwi tokenizer: ['록시', '땅', '핸드', '크림']
# article title: 반상기 세트 (미개봉)
# ------------------------------------------------------------
# bpe tokenizer: ['반상기', '세트', '미개봉']
# kiwi tokenizer: ['상기', '세트', '개봉']
# article title: 현대백화점 한우순우리 국 선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['현대백화점', '한우', '선물세트']
# kiwi tokenizer: ['현대백화점', '한우', '우리', '국', '선물', '세트']
# article title: brunello cucinelli
# ------------------------------------------------------------
# bpe tokenizer: ['un', 'el', 'in', 'el']
# kiwi tokenizer: []
# article title: 미개봉 선물용) 구름인형 1개 + 키체인 인형 1개 세트
# ------------------------------------------------------------
# bpe tokenizer: ['미개봉', '선물용', '인형', '1개', '인형', '1개', '세트']
# kiwi tokenizer: ['개봉', '선물', '구름', '인형', '개', '키체', '인형', '개', '세트']
# article title: 기펠 도마
# ------------------------------------------------------------
# bpe tokenizer: ['기펠', '도마']
# kiwi tokenizer: ['기펠']
# article title: 스팸 선물세트 8E호
# ------------------------------------------------------------
# bpe tokenizer: ['스팸', '선물세트', '8e호']
# kiwi tokenizer: ['스팸', '선물', '세트', '호']
# article title: 한국도자기 은나노 2인 세트
# ------------------------------------------------------------
# bpe tokenizer: ['한국도자기', '2인', '세트']
# kiwi tokenizer: ['한국', '도자기', '나노', '인', '세트']
# article title: 동원참치 리챔 선물세트 팝니다
# ------------------------------------------------------------
# bpe tokenizer: ['동원참치', '리챔', '선물세트', '팝니다']
# kiwi tokenizer: ['동원', '참치', '채', 'ᆷ', '선물', '세트', '파']
# article title: 추석 선물로 받은 동원참치 리챔 세트 팔아요!
# ------------------------------------------------------------
# bpe tokenizer: ['추석', '선물로', '받은', '동원참치', '리챔', '세트', '팔아요']
# kiwi tokenizer: ['추석', '선물', '동원', '참치', '채', 'ᆷ', '세트', '팔']
# article title: 프레쉬 핸드크림 향수 선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['프레쉬', '핸드크림', '향수', '선물세트']
# kiwi tokenizer: ['프레', '핸드', '크림', '향수', '선물', '세트']
# article title: 다예국산차8종선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['8종', '선물세트']
# kiwi tokenizer: ['다예국산차8종', '선물', '세트']
# article title: 반트 VANT 화장품세트 총 5가지 새제품
# ------------------------------------------------------------
# bpe tokenizer: ['an', '화장품세트', '가지', '새제품']
# kiwi tokenizer: ['화장품', '세트', '가지', '제품']
# article title: 타임 포터블 향수 세트 [미사용]
# ------------------------------------------------------------
# bpe tokenizer: ['타임', '향수', '세트', '미사용']
# kiwi tokenizer: ['타임', '포터블', '향수', '세트', '미', '사용']
# article title: 닥스 넥타이 양말 셋트
# ------------------------------------------------------------
# bpe tokenizer: ['닥스', '넥타이', '양말', '셋트']
# kiwi tokenizer: ['닥스', '넥타이', '양말', '셋트']
# article title: (새상품)정품 독일 하이드로마 조리도구 7종 세트
# ------------------------------------------------------------
# bpe tokenizer: ['새상품', '정품', '독일', '하이드', '조리도구', '7종', '세트']
# kiwi tokenizer: ['상품', '품', '독일', '하이드', '로마', '조리', '도구', '종', '세트']
# article title: 새제품) 독일 콕스타 젬마 칼 6종세트
# ------------------------------------------------------------
# bpe tokenizer: ['새제품', '독일', '스타', '6종세트']
# kiwi tokenizer: ['제품', '독일', '콕', '스타', 'ᆷ', '칼', '종', '세트']
# article title: 닌텐도 스위치 링피트 어드밴처(미개봉)
# ------------------------------------------------------------
# bpe tokenizer: ['닌텐도', '스위치', '피트', '어드밴', '미개봉']
# kiwi tokenizer: ['닌텐도', '스위치', '링', '피트', '어드밴', '처', '개봉']
# article title: 차바이오 에버셀 화장품 4주분(새상품)
# ------------------------------------------------------------
# bpe tokenizer: ['바이오', '에버', '화장품', '새상품']
# kiwi tokenizer: ['차', '바이오', '에버', '화장품', '주', '분', '상품']
# article title: 불가리 정품 향수) 새상품 / 5개 미니어처 셋트
# ------------------------------------------------------------
# bpe tokenizer: ['불가리', '정품', '향수', '새상품', '5개', '미니어처', '셋트']
# kiwi tokenizer: ['불가리', '정품', '향수', '상품', '개', '미니어', '처', '셋트']
# article title: 르네휘테르 두피 스케일링
# ------------------------------------------------------------
# bpe tokenizer: ['르네', '휘테르']
# kiwi tokenizer: ['르네휘테', '르', '두피', '스케일링']
# article title: (새상품) 록시땅 핸드크림 앤 립밤 듀오세트!!
# ------------------------------------------------------------
# bpe tokenizer: ['새상품', '록시땅', '핸드크림', '립밤', '듀오세트']
# kiwi tokenizer: ['상품', '록시', '땅', '핸드', '크림', '앤', '립밤', '듀오', '세트']
# article title: 아베다 샴푸, 너처링 샴푸셋트, 선물가능
# ------------------------------------------------------------
# bpe tokenizer: ['아베다', '샴푸', '샴푸', '셋트', '선물가능']
# kiwi tokenizer: ['아베', '샴푸', '너처', '링', '샴푸', '셋', '선물', '가능']
# article title: [빈티지] 로얄알버트 스위트 바이올렛 샐러드디쉬 4pcs 세트(21cm)
# ------------------------------------------------------------
# bpe tokenizer: ['빈티지', '로얄알버트', '스위트', '바이', '샐러', '4pcs', '세트', '21', 'cm']
# kiwi tokenizer: ['빈티지', '로얄알버', '위트', '바이올렛', '샐러드', '세트']
# article title: 쁘리마쥬 태열키트(세럼, 고보습 크림) 새상품
# ------------------------------------------------------------
# bpe tokenizer: ['키트', '세럼', '보습', '크림', '새상품']
# kiwi tokenizer: ['쁘리마쥬', '태열키', 'ᆷ', '보습', '크림', '상품']
# article title: 티파니 앤 코 머그컵 새상품
# ------------------------------------------------------------
# bpe tokenizer: ['티파니', '머그컵', '새상품']
# kiwi tokenizer: ['티파니', '앤', '코', '머그', '컵', '상품']
# article title: 샹시아 Shang Xia Bamboo Tea cup set(새제품/쇼핑백)
# ------------------------------------------------------------
# bpe tokenizer: ['시아', 'sh', 'an', 'am', 'bo', 'tea', 'set', '새제품', '쇼핑백']
# kiwi tokenizer: ['샹시', '제품', '쇼핑백']
# article title: 아모레퍼시픽 기프트세트
# ------------------------------------------------------------
# bpe tokenizer: ['아모레퍼시픽', '기프트세트']
# kiwi tokenizer: ['아모레퍼시픽', '기프트', '세트']
# article title: 새상품 씨드느와 남성 골프  웨어 상하의 세트 겨울/ 니트/ 바지
# ------------------------------------------------------------
# bpe tokenizer: ['새상품', '남성', '골프', '웨어', '상하의', '세트', '겨울', '니트', '바지']
# kiwi tokenizer: ['상품', '씨드느', '남성', '골프', '웨어', '상하', '세트', '겨울', '니트', '바지']
# article title: 오설록 프리미엄 티 컬렉션 (새상품)
# ------------------------------------------------------------
# bpe tokenizer: ['오설록', '프리미엄', '컬렉션', '새상품']
# kiwi tokenizer: ['오설록', '프리미엄', '티', '컬렉션', '상품']
# article title: 동원참치캔 선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['동원참치', '선물세트']
# kiwi tokenizer: ['동원', '참치', '캔', '선물', '세트']
# article title: (완전새제품)아모레퍼시픽 추석선물세트 (쇼핑백포함)
# ------------------------------------------------------------
# bpe tokenizer: ['완전', '새제품', '아모레퍼시픽', '추석선물세트', '쇼핑백포함']
# kiwi tokenizer: ['완전', '제품', '아모레퍼시픽', '추석', '선물', '세트', '쇼핑백', '포함']
# article title: (새상품) 독일 콕스타 핸드블렌더 믹서기 다지기 반죽기(집들이선물)
# ------------------------------------------------------------
# bpe tokenizer: ['새상품', '독일', '스타', '핸드', '블렌', '지기', '집들이선물']
# kiwi tokenizer: ['상품', '독일', '콕스', '핸드', '블렌더', '믹서기', '반죽', '집', '선물']
# article title: 에스티로더 화장품
# ------------------------------------------------------------
# bpe tokenizer: ['에스티로더', '화장품']
# kiwi tokenizer: ['에스티로', '화장품']
# article title: 볼보 지갑세트
# ------------------------------------------------------------
# bpe tokenizer: ['지갑', '세트']
# kiwi tokenizer: ['볼보', '지갑', '세트']
# article title: (새제품)스팸 클래식 3호 판매
# ------------------------------------------------------------
# bpe tokenizer: ['새제품', '스팸', '클래식', '3호', '판매']
# kiwi tokenizer: ['제품', '스팸', '클래식', '호', '판매']
# article title: 일본 요가복 m 상하의 세트 새상품🐰🥕
# ------------------------------------------------------------
# bpe tokenizer: ['일본', '요가', '상하의', '세트', '새상품']
# kiwi tokenizer: ['일본', '요가', '복', '상하', '세트', '상품']
# article title: 새제품)베르티니 황금 골프공 3구 골프볼마커 선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['새제품', '베르', '골프공', '골프', '볼마커', '선물세트']
# kiwi tokenizer: ['제품', '베르티', '황금', '골프공', '3구', '골프볼마', '커', '선물', '세트']
# article title: 김소형 녹용침향환 30환 선물 건강 효도 추석
# ------------------------------------------------------------
# bpe tokenizer: ['소형', '녹용', '침향', '30', '선물', '건강', '추석']
# kiwi tokenizer: ['김소형', '녹용침향', '환', '환', '선물', '건강', '효도', '추석']
# article title: 암웨이 글리스터 치약 칫솔 세트
# ------------------------------------------------------------
# bpe tokenizer: ['암웨이', '리스', '치약', '칫솔', '세트']
# kiwi tokenizer: ['암웨이', '글리스', '터', '치약', '칫솔', '세트']
# article title: 어린이날 선물 새상품) 키모치스 구름인형 1개 + 키체인인형 1개 셋트
# ------------------------------------------------------------
# bpe tokenizer: ['어린이', '선물', '새상품', '인형', '1개', '체인', '인형', '1개', '셋트']
# kiwi tokenizer: ['어린이날', '선물', '상품', '키모치', '구름', '인형', '개', '키체', '인형', '개', '셋트']
# article title: (새상품) 록시땅 핸드크림 & 립밤
# ------------------------------------------------------------
# bpe tokenizer: ['새상품', '록시땅', '핸드크림', '립밤']
# kiwi tokenizer: ['상품', '록시', '땅', '핸드', '크림', '립밤']
# article title: 스팸선물세트 8호
# ------------------------------------------------------------
# bpe tokenizer: ['스팸선물세트', '8호']
# kiwi tokenizer: ['스팸', '선물', '세트', '호']
# article title: (새제품) 고려 진홍삼 골드 30포 세트
# ------------------------------------------------------------
# bpe tokenizer: ['새제품', '홍삼', '골드', '30포', '세트']
# kiwi tokenizer: ['제품', '고려', '진홍', '삼', '골드', '포', '세트']
# article title: 오뚜기 선물세트 특선 E호 팔아요
# ------------------------------------------------------------
# bpe tokenizer: ['오뚜기', '선물세트', '특선', 'e호', '팔아요']
# kiwi tokenizer: ['오뚜기', '선물', '세트', '특선', '호', '팔']
# article title: 클로리스 시그니처 티 세트
# ------------------------------------------------------------
# bpe tokenizer: ['클로', '리스', '시그니처', '세트']
# kiwi tokenizer: ['클로', '리스', '시그니', '처', '티', '세트']
# article title: 새제품) 남성 나이키 피어오브갓 바스켓볼 스트링 자켓 세트 S
# ------------------------------------------------------------
# bpe tokenizer: ['새제품', '남성', '나이키', '오브', '바스', '스트', '자켓', '세트']
# kiwi tokenizer: ['제품', '남성', '나이키', '피어오브', '바스켓', '스트', '링', '자켓', '세트']
# article title: 더프트앤도프트 핸드크림 선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['더프트앤도프트', '핸드크림', '선물세트']
# kiwi tokenizer: ['더프트앤도프', '핸드', '크림', '선물', '세트']
# article title: 로스팅타이거세트
# ------------------------------------------------------------
# bpe tokenizer: ['로스', '타이', '세트']
# kiwi tokenizer: ['로스팅타이거', '세트']
# article title: 논픽션 베스트 4종 세트 미개봉
# ------------------------------------------------------------
# bpe tokenizer: ['논픽션', '베스트', '4종', '세트', '미개봉']
# kiwi tokenizer: ['논픽션', '베스트', '종', '세트', '개봉']
# article title: 🦄레녹스 귀요미 찻잔세트 (새상품)🦄
# ------------------------------------------------------------
# bpe tokenizer: ['레녹스', '찻잔세트', '새상품']
# kiwi tokenizer: ['레녹스', '귀요', '미', '찻잔', '세트', '상품']
# article title: 교촌치킨 허니순살 감자튀김
# ------------------------------------------------------------
# bpe tokenizer: ['교촌치킨', '허니']
# kiwi tokenizer: ['교촌', '치킨', '허니순', '감자튀김']
# article title: 에스콰이어 지갑 키홀더 세트 선물용 택포가격
# ------------------------------------------------------------
# bpe tokenizer: ['에스', '지갑', '홀더', '세트', '선물용', '가격']
# kiwi tokenizer: ['에스콰이어', '지갑', '키홀', '세트', '선물', '택포', '가격']
# article title: 스와로브스키 진주 크리스탈 큐빅진주 목걸이셋트
# ------------------------------------------------------------
# bpe tokenizer: ['스와로브스키', '진주', '크리스탈', '진주', '목걸이', '셋트']
# kiwi tokenizer: ['스와로브스키', '진주', '크리스탈', '큐빅', '진주', '목걸이', '셋트']
# article title: 베이비기프트세트(곰돌이 아기옷 케이크) 새상품
# ------------------------------------------------------------
# bpe tokenizer: ['베이비', '기프트세트', '곰돌이', '아기옷', '케이크', '새상품']
# kiwi tokenizer: ['베이비기프트', '세트', '곰', '돌', '아기', '옷', '케이크', '상품']
# article title: 옥 목걸이+귀걸이 세트입니다.
# ------------------------------------------------------------
# bpe tokenizer: ['목걸이', '귀걸이', '세트입니다']
# kiwi tokenizer: ['옥', '목걸이', '귀걸이', '세트']
# article title: 그릇세트 캣티 컬렉션 가져가세유💘(~2/6까지)
# ------------------------------------------------------------
# bpe tokenizer: ['그릇세트', '컬렉션', '가져가', '까지']
# kiwi tokenizer: ['그릇', '세트', '캣', '티', '컬렉션', '세유']
# article title: [새상품/선물]해동찬가 선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['새상품', '선물', '선물세트']
# kiwi tokenizer: ['상품', '선물', '해동', '찬가', '선물', '세트']
# article title: 스팸선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['스팸선물세트']
# kiwi tokenizer: ['스팸', '선물', '세트']
# article title: (새상품) 록시땅 필로우 미스트 선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['새상품', '록시땅', '필로우', '미스트', '선물세트']
# kiwi tokenizer: ['상품', '록시', '땅', '필', '우', '미스트', '선물', '세트']
# article title: 에코프랜드 술잔,찻잔세트 판매
# ------------------------------------------------------------
# bpe tokenizer: ['에코', '랜드', '술잔', '찻잔세트', '판매']
# kiwi tokenizer: ['에코프', '랜드', '술잔', '찻잔', '세트', '판매']
# article title: 금수산애 쌀선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['선물세트']
# kiwi tokenizer: ['금수산', '애', '쌀', '선물', '세트']
# article title: 조셉 조셉 캐러셀 조리도구 키친툴 7개 거치대 새상품
# ------------------------------------------------------------
# bpe tokenizer: ['조리도구', '키친', '7개', '거치대', '새상품']
# kiwi tokenizer: ['조셉', '조셉', '러셀', '조리', '도구', '키친', '툴', '개', '상품']
# article title: 새상품) 수저 10개 세트
# ------------------------------------------------------------
# bpe tokenizer: ['새상품', '수저', '10개', '세트']
# kiwi tokenizer: ['상품', '수저', '개', '세트']
# article title: (새상품) 아쿠아디파르마 향수 30ml ,립밤 15ml 2종 일괄판매
# ------------------------------------------------------------
# bpe tokenizer: ['새상품', '아쿠', '아디', '르마', '향수', '30ml', '립밤', '15ml', '2종', '일괄판매']
# kiwi tokenizer: ['상품', '아쿠아디파르', '마', '향수', '립밤', '종', '일괄', '판매']
# article title: [빈티지] 바바리아 소오목그릇 2pcs 세트(12cm)
# ------------------------------------------------------------
# bpe tokenizer: ['빈티지', '바바', '리아', '그릇', 'pcs', '세트', '12', 'cm']
# kiwi tokenizer: ['빈티지', '바바리아', '소오목', '그릇', '세트']
# article title: 목걸이 &귀걸이 셋트
# ------------------------------------------------------------
# bpe tokenizer: ['목걸이', '귀걸이', '셋트']
# kiwi tokenizer: ['목걸이', '귀걸이', '셋트']
# article title: 동원참치 친 100호 선물세트 팝니다
# ------------------------------------------------------------
# bpe tokenizer: ['동원참치', '100호', '선물세트', '팝니다']
# kiwi tokenizer: ['동원', '참치', '호', '선물', '세트', '파']
# article title: 프라다 머니클립
# ------------------------------------------------------------
# bpe tokenizer: ['프라다']
# kiwi tokenizer: ['프라다', '머니클', '리', 'ᆸ']
# article title: 리멘트 리락쿠마 소중한 선물세트 4번
# ------------------------------------------------------------
# bpe tokenizer: ['선물세트']
# kiwi tokenizer: ['리', '멘트', '리락쿠마', '선물', '세트', '번']
# article title: 한국도자기 4인조 반상기.밥공기, 국그릇.새상품
# ------------------------------------------------------------
# bpe tokenizer: ['한국도자기', '4인조', '반상기', '밥공기', '국그릇', '새상품']
# kiwi tokenizer: ['한국', '도자기', '인', '조', '반상', '밥', '공기', '국그릇', '상품']
# article title: 선물세트 한우선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['선물세트', '한우', '선물세트']
# kiwi tokenizer: ['선물', '세트', '한우', '선물', '세트']
# article title: [새제품]스틸라 아이섀도우 팔레트 + 금손브러쉬세트 + 손거울
# ------------------------------------------------------------
# bpe tokenizer: ['새제품', '스틸라', '아이섀도우', '팔레트', '브러쉬세트', '손거울']
# kiwi tokenizer: ['제품', '스틸', '아이섀도우', '팔레트', '금손브러쉬', '세트', '손거울']
# article title: 스팸 선물세트 21호(200g x 16) 팝니다
# ------------------------------------------------------------
# bpe tokenizer: ['스팸', '선물세트', '21호', '200g', '16', '팝니다']
# kiwi tokenizer: ['스팸', '선물', '세트', '호', '파']
# article title: 글라스락 후라이팬 22,28 cm IH가능한 2세트 새제품
# ------------------------------------------------------------
# bpe tokenizer: ['글라스락', '후라이팬', '28', 'cm', '가능', '2세트', '새제품']
# kiwi tokenizer: ['글라스', '락', '후라이', '팬', '가능', '세트', '제품']
# article title: 히말라야 핑크솔트 스페셜 선물세트 팝니다
# ------------------------------------------------------------
# bpe tokenizer: ['히말라야', '핑크솔트', '스페셜', '선물세트', '팝니다']
# kiwi tokenizer: ['히말라야', '핑크', '솔', '스페셜', '선물', '세트', '파']
# article title: 스와로브스키 크리스탈 팔찌 미시착 새상품 팝니다!
# ------------------------------------------------------------
# bpe tokenizer: ['스와로브스키', '크리스탈', '팔찌', '새상품', '팝니다']
# kiwi tokenizer: ['스와로브스키', '크리스탈', '팔찌', '미시', '착', '상품']
# article title: 새상품) 수저 10개 세트
# ------------------------------------------------------------
# bpe tokenizer: ['새상품', '수저', '10개', '세트']
# kiwi tokenizer: ['상품', '수저', '개', '세트']
# article title: 선물용 폴스미스 카드지갑+양말3개셋트(원가 39만원)
# ------------------------------------------------------------
# bpe tokenizer: ['선물용', '스미', '카드지갑', '양말', '3개', '셋트', '원가', '만원']
# kiwi tokenizer: ['선물', '폴', '스미스', '카드', '지갑', '양말', '개', '셋트', '원가', '만', '원']
# article title: 다이나톤 DCP-870 디지털피아노
# ------------------------------------------------------------
# bpe tokenizer: ['다이', '70', '피아']
# kiwi tokenizer: ['다이나톤', '디지털', '피아노']
# article title: 스팸3호 선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['스팸3호', '선물세트']
# kiwi tokenizer: ['스팸', '호', '선물', '세트']
# article title: 정품회 배 7.5kg 선물세트 (보자기 포함)
# ------------------------------------------------------------
# bpe tokenizer: ['정품', '5kg', '선물세트', '보자기', '포함']
# kiwi tokenizer: ['정품', '회', '배', '선물', '세트', '보자기', '포함']
# article title: 에시앙 아기의자 p-edition 크라운2종 풀세트
# ------------------------------------------------------------
# bpe tokenizer: ['에시앙', '아기', '의자', 'di', 'tion', '크라운', '2종', '풀세트']
# kiwi tokenizer: ['시앙', '아기', '크라운', '종', '풀', '세트']
# article title: 2인 커피잔세트
# ------------------------------------------------------------
# bpe tokenizer: ['2인', '커피잔세트']
# kiwi tokenizer: ['커피', '잔', '세트']
# article title: LG선물세트 뉴에디션 s호
# ------------------------------------------------------------
# bpe tokenizer: ['lg', '선물세트', '에디션', 's호']
# kiwi tokenizer: ['선물', '세트', '뉴에디', '호']
# article title: 브리오 스마트테크-액션 터널 전동기차 세트(33873)
# ------------------------------------------------------------
# bpe tokenizer: ['브리', '스마트', '전동', '세트']
# kiwi tokenizer: ['브리', '스마트테', '액션', '터널', '전동기', '차', '세트']
# article title: 남자 런닝 100사이즈1, 특허 받은 팬티 100사이즈 1개, 양말 1개 선물셋트 새것(새상품)판매 합니다
# ------------------------------------------------------------
# bpe tokenizer: ['남자', '100', '사이즈', '받은', '팬티', '100사이즈', '1개', '양말', '1개', '선물셋트', '새것', '새상품', '판매', '합니다']
# kiwi tokenizer: ['남자', '런닝', '사이즈', '특허', '팬티', '사이즈', '개', '양말', '개', '선물', '셋', '새것', '상품', '판매']
# article title: 신세계백화점 천안배 VIP 7~8입 (5.8kg내외) 새상품 선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['신세', '백화점', 'vi', '새상품', '선물세트']
# kiwi tokenizer: ['신세계백화점', '천안', '배', '입', '내외', '상품', '선물', '세트']
# article title: SAINT-YVES 핵진주 귀걸이 & 목걸이 세트 혹은 단품
# ------------------------------------------------------------
# bpe tokenizer: ['in', 'es', '진주', '귀걸이', '목걸이', '세트']
# kiwi tokenizer: ['핵', '진주', '귀걸이', '목걸이', '세트', '단', '품']
# article title: [추석 선물] YUNJAC 연작 화장품 선물셋트(정품, 미개봉)
# ------------------------------------------------------------
# bpe tokenizer: ['추석', '선물', 'un', '연작', '화장품', '선물셋트', '정품', '미개봉']
# kiwi tokenizer: ['추석', '선물', '연작', '화장품', '선물', '셋트', '정품', '개봉']
# article title: 롯데 백화점. 푸드 에비뉴. 방금 받은 팔각 사과 세트
# ------------------------------------------------------------
# bpe tokenizer: ['롯데', '백화점', '푸드', '받은', '사과', '세트']
# kiwi tokenizer: ['롯데', '백화점', '푸드', '비', '뉴', '팔각', '사과', '세트']
# article title: 미사용 앤틱 독일 나이프세트 ANTON WINGEN
# ------------------------------------------------------------
# bpe tokenizer: ['미사용', '독일', '나이', '세트', 'an', 'on', 'in', 'en']
# kiwi tokenizer: ['미사', '앤틱', '독일', '나이프', '세트']
# article title: (미개봉새것)동물볼링놀이 완구 장난감
# ------------------------------------------------------------
# bpe tokenizer: ['미개봉', '새것', '동물', '놀이', '장난감']
# kiwi tokenizer: ['개봉', '것', '동물', '볼링', '놀이', '완구', '장난감']
# article title: 블라호 디퓨저,핸드크림,핸드워시 선물셋트팝니다~
# ------------------------------------------------------------
# bpe tokenizer: ['블라', '디퓨저', '핸드크림', '핸드워시', '선물셋트', '팝니다']
# kiwi tokenizer: ['블라', '호', '디퓨', '핸드', '크림', '핸드워', '시', '선물셋트', '파']
# article title: 아모레퍼시픽 타임 레스폰스 선물 세트 🎁💝
# ------------------------------------------------------------
# bpe tokenizer: ['아모레퍼시픽', '타임', '레스', '선물', '세트']
# kiwi tokenizer: ['아모레퍼시픽', '타임', '레스폰', '선물', '세트']
# article title: 새상품) 댕댕츄정 선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['새상품', '선물세트']
# kiwi tokenizer: ['상품', '댕댕츄', '정', '선물', '세트']
# article title: 동원 참치 친100호 라이트스탠다드 12개 선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['동원', '참치', '100호', '라이트', '스탠', '12개', '선물세트']
# kiwi tokenizer: ['동원', '참치', '호', '라이트', '스탠다드', '개', '선물', '세트']
# article title: 러쉬(LUSH) 릴렉스 홈스파set(새것)
# ------------------------------------------------------------
# bpe tokenizer: ['러쉬', 'lush', '렉스', '스파', 'set', '새것']
# kiwi tokenizer: ['러', '릴', '렉스', '홈스', '파', '것']
# article title: 무드매쳐 반전립스틱 6종세트(새상품)
# ------------------------------------------------------------
# bpe tokenizer: ['무드', '립스틱', '6종세트', '새상품']
# kiwi tokenizer: ['무드매', '반전', '립스틱', '종', '세트', '상품']
# article title: (새상품) 발뮤다 하리오 핸드드립 세트 판매해요
# ------------------------------------------------------------
# bpe tokenizer: ['새상품', '리오', '핸드드립', '세트', '판매해요']
# kiwi tokenizer: ['상품', '발뮤', '핸드', 'ᆸ', '세트', '판매']
# article title: (카카오선물택배)비스테까 티라미수 골드피콜로 3구세트(3가지맛)
# ------------------------------------------------------------
# bpe tokenizer: ['카카오', '선물', '스테', '골드', '구세트']
# kiwi tokenizer: ['카카오선물', '택배', '비스테', '까', '티라미수', '골드피콜', '구', '세트', '가지', '맛']
# article title: 캘러웨이 캐디백 보스턴백 세트
# ------------------------------------------------------------
# bpe tokenizer: ['캘러웨이', '캐디백', '보스턴백', '세트']
# kiwi tokenizer: ['캘러웨', '캐디', '백', '보스턴', '백', '세트']
# article title: MSGM 키즈 트레이닝 세트+무료나눔 8y
# ------------------------------------------------------------
# bpe tokenizer: ['키즈', '트레이닝', '세트', '무료나눔']
# kiwi tokenizer: ['키즈', '트레이닝', '세트', '무료', 'ᆷ']
# article title: 록시땅 플로럴 바디 3종세크 새제품!
# ------------------------------------------------------------
# bpe tokenizer: ['록시땅', '플로럴', '바디', '3종', '새제품']
# kiwi tokenizer: ['록시', '땅', '플로', '럴', '바디', '3종세', '제품']
# article title: 설화수 자음생 2종 (+기초견본 4종)
# ------------------------------------------------------------
# bpe tokenizer: ['설화수', '자음생', '2종', '기초', '4종']
# kiwi tokenizer: ['설화', '수', '자음', '종', '기초', '견본', '종']
# article title: 베르사체 브라이트 크리스탈 EDT 30ml세트
# ------------------------------------------------------------
# bpe tokenizer: ['베르사체', '브라이트', '크리스탈', 'ed', '30', 'ml', '세트']
# kiwi tokenizer: ['베르사체', '브', '라이트', '크리스탈', '세트']
# article title: 허브티 선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['허브티', '선물세트']
# kiwi tokenizer: ['허브', '티', '선물', '세트']
# article title: 수건 선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['수건', '선물세트']
# kiwi tokenizer: ['수건', '선물', '세트']
# article title: [새상품] 한국도자기젠 델피 공기대접세트 8p
# ------------------------------------------------------------
# bpe tokenizer: ['새상품', '한국', '도자기', '공기', '세트', '8p']
# kiwi tokenizer: ['상품', '한국', '도자기', '데', '공기', '대접', '세트']
# article title: 나무젓가락 새제품
# ------------------------------------------------------------
# bpe tokenizer: ['나무', '젓가락', '새제품']
# kiwi tokenizer: ['나무젓가락', '제품']
# article title: 청와대 찻잔세트 티스푼 새상품 명절선물용
# ------------------------------------------------------------
# bpe tokenizer: ['청와대', '찻잔세트', '티스푼', '새상품', '명절', '선물용']
# kiwi tokenizer: ['청와대', '찻잔', '세트', '티스푼', '상품', '명절', '선물']
# article title: 라프레리 스킨캐비어 아이 + 수프림밤클렌저 (새제품)
# ------------------------------------------------------------
# bpe tokenizer: ['프레', '스킨', '캐비어', '아이', '클렌저', '새제품']
# kiwi tokenizer: ['라프레', '리', '스킨캐비', '수프림밤', '클렌저', '제품']
# article title: 빅토리아 에그팩 비누 세트 + 케이스 2개
# ------------------------------------------------------------
# bpe tokenizer: ['빅토리아', '비누', '세트', '케이스', '2개']
# kiwi tokenizer: ['빅토리아', '팩', '비누', '세트', '케이스', '개']
# article title: [새상품]이솝 핸드밤&립밤
# ------------------------------------------------------------
# bpe tokenizer: ['새상품', '이솝', '핸드밤', '립밤']
# kiwi tokenizer: ['상품', '이솝', '핸드', '밤', '립밤']
# article title: 베이비뵨 캐리어원 실버 매쉬 아기띠
# ------------------------------------------------------------
# bpe tokenizer: ['베이비', '리어', '실버', '아기띠']
# kiwi tokenizer: ['베이비뵨', '캐리', '어원', '실버', '아기', '띠']
# article title: 록시땅 바디워시 & 핸드크림
# ------------------------------------------------------------
# bpe tokenizer: ['록시땅', '바디워시', '핸드크림']
# kiwi tokenizer: ['록시', '땅', '바디워', '시', '핸드', '크림']
# article title: 노르디스크 컵도마 셋트(새제품)
# ------------------------------------------------------------
# bpe tokenizer: ['디스', '도마', '셋트', '새제품']
# kiwi tokenizer: ['노르', '디스크', '컵', '도마', '셋트', '제품']
# article title: 카누 선물세트 새상품
# ------------------------------------------------------------
# bpe tokenizer: ['카누', '선물세트', '새상품']
# kiwi tokenizer: ['카누', '선물', '세트', '상품']
# article title: 에르메스 향수 바디로션 선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['에르메스', '향수', '바디로션', '선물세트']
# kiwi tokenizer: ['에르메스', '향수', '바디', '로션', '선물', '세트']
# article title: 꼬달리 에센스미스트 핸드크림 비노퍼펙트세럼 토너 선물세트 (미개봉품)
# ------------------------------------------------------------
# bpe tokenizer: ['꼬달리', '에센스', '미스트', '핸드크림', '퍼펙', '세럼', '토너', '선물세트', '미개봉품']
# kiwi tokenizer: ['에센스', '미스', '핸드', '크림', '비노퍼펙트세', 'ᆷ', '토너', '선물', '세트', '개봉', '품']
# article title: (새 제품)스타벅스 머그잔 세트
# ------------------------------------------------------------
# bpe tokenizer: ['제품', '스타벅스', '머그잔', '세트']
# kiwi tokenizer: ['제품', '스타벅스', '머그잔', '세트']
# article title: 폴란드 티팟세트.워머 과 찻잔세트 판매합니다. 폴란드서 직접 선물받은거라 문양이 흔치 않아요.
# ------------------------------------------------------------
# bpe tokenizer: ['폴란드', '티팟세트', '워머', '찻잔세트', '판매합니다', '폴란', '선물받', '아요']
# kiwi tokenizer: ['폴란드', '티팟', '세트', '찻잔', '세트', '판매', '폴란드', '선물', '거', '문양', '흔']
# article title: 스팸 카놀라유 올리고당 선물세트 새거 만원
# ------------------------------------------------------------
# bpe tokenizer: ['스팸', '카놀라유', '올리고당', '선물세트', '새거', '만원']
# kiwi tokenizer: ['스팸', '카노', 'ᆯ라유', '당', '선물', '세트', '거', '만', '원']
# article title: <새상품>화숙리 푸시업 브라 80A
# ------------------------------------------------------------
# bpe tokenizer: ['새상품', '브라', '80']
# kiwi tokenizer: ['상품', '화숙', '리', '푸시', '업', '브']
# article title: 포트메이슨티 선물세트, 홍차선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['포트', '메이', '선물세트', '차선물세트']
# kiwi tokenizer: ['포트', '메이슨', '티', '선물', '세트', '홍차', '선물', '세트']
# article title: 캐스키드슨 바디 6종 세트(미개봉 새상품)
# ------------------------------------------------------------
# bpe tokenizer: ['캐스키드슨', '바디', '6종', '세트', '미개봉', '새상품']
# kiwi tokenizer: ['캐스', '키드', '바디', '종', '세트', '개봉', '상품']
# article title: Iwlt 샴푸 컨디셔너 세트 헤어케어
# ------------------------------------------------------------
# bpe tokenizer: ['샴푸', '컨디셔너', '세트', '헤어', '케어']
# kiwi tokenizer: ['샴푸', '컨디셔', '너', '세트', '헤어케']
# article title: 이케아 농장 장난감 인형 세트 ikea farmhouse soft animal set
# ------------------------------------------------------------
# bpe tokenizer: ['이케아', '장난감', '인형', '세트', 'ea', 'ar', 'us', 'so', 'an', 'ma', 'set']
# kiwi tokenizer: ['이케아', '농장', '장난감', '인형', '세트']
# article title: 러쉬 배쓰밤 섹스밤 사쿠라 로즈 잼 버블룬 세트
# ------------------------------------------------------------
# bpe tokenizer: ['러쉬', '배쓰밤', '섹스밤', '사쿠라', '로즈', '버블', '세트']
# kiwi tokenizer: ['러', '배쓰', '밤', '섹스', '밤', '사쿠라', '로즈', '잼', '버블', '세트']
# article title: 양키캔들 프레시 컷 로즈 소 모자이크 자쉐이드 선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['양키캔들', '프레시', '로즈', '모자이크', '자쉐이드', '선물세트']
# kiwi tokenizer: ['양키', '캔', '프레', '시', '컷', '로즈', '모자이크', '자쉐', '이드', '선물', '세트']
# article title: 르쿠르제 티팟세트 (4p)
# ------------------------------------------------------------
# bpe tokenizer: ['르쿠르제', '티팟세트', '4p']
# kiwi tokenizer: ['르쿠르', '저', '티팟', '세트']
# article title: Twinings 트와이닝 차 티백 세트 45T
# ------------------------------------------------------------
# bpe tokenizer: ['tw', 'in', 'in', '트와이닝', '티백', '세트']
# kiwi tokenizer: ['트와', '이닝', '차', '티백', '세트']
# article title: cj선물세트 s호
# ------------------------------------------------------------
# bpe tokenizer: ['cj선물세트', 's호']
# kiwi tokenizer: ['선물', '세트', '호']
# article title: 타이틀리스트 볼라이너 셋 새제품
# ------------------------------------------------------------
# bpe tokenizer: ['타이틀리스트', '라이', '새제품']
# kiwi tokenizer: ['타이틀', '리스트', '볼라', '너', '셋', '제품']
# article title: 제너 독일 냄비 세트
# ------------------------------------------------------------
# bpe tokenizer: ['제너', '독일', '냄비', '세트']
# kiwi tokenizer: ['저', '너', '독일', '냄비', '세트']
# article title: 벤타나 고양이 윈도우 해먹.스텝 켓월.장난감 팔아여
# ------------------------------------------------------------
# bpe tokenizer: ['타나', '고양이', '도우', '장난감', '팔아']
# kiwi tokenizer: ['벤타', '고양이', '윈도우', '스텝', '켓', '월', '장난감']
# article title: 우리농산 참기름 선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['우리', '참기름', '선물세트']
# kiwi tokenizer: ['우리', '농사', '참기름', '선물', '세트']
# article title: 딥티크 차량용 방향제 세트  (베이) / 미개봉 새상품
# ------------------------------------------------------------
# bpe tokenizer: ['딥티크', '차량용', '방향제', '세트', '미개봉', '새상품']
# kiwi tokenizer: ['딥티', '차량', '방향제', '세트', '개봉', '상품']
# article title: 샹달프 미니잼 선물세트. 12종
# ------------------------------------------------------------
# bpe tokenizer: ['샹달', '미니', '선물세트', '12종']
# kiwi tokenizer: ['샹달', '미니', '잼', '선물', '세트', '종']
# article title: [새제품] 클로리스 티백 10p 선물 세트
# ------------------------------------------------------------
# bpe tokenizer: ['새제품', '클로', '리스', '티백', '10p', '선물', '세트']
# kiwi tokenizer: ['제품', '클로', '리스', '티백', '선물', '세트']
# article title: (새상품) 록시땅 프루티 립틴트밤 세트 (선셋프로방스)
# ------------------------------------------------------------
# bpe tokenizer: ['새상품', '록시땅', '세트', '프로']
# kiwi tokenizer: ['상품', '록시', '땅', '프루', '티', '립틴트', '밤', '세트', '선셋', '프로방스']
# article title: 히말라야 블랙솔트 입욕제 세트
# ------------------------------------------------------------
# bpe tokenizer: ['히말라야', '블랙', '솔트', '입욕제', '세트']
# kiwi tokenizer: ['히말라야', '블랙', '솔', '입욕', '세트']
# article title: Lush 샤워젤 선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['lush', '샤워젤', '선물세트']
# kiwi tokenizer: ['샤워', '젤', '선물', '세트']
# article title: 스타벅스 체리블라썸 보온 케틀 / 보온주전자 / 보온병
# ------------------------------------------------------------
# bpe tokenizer: ['스타벅스', '체리블라썸', '보온', '주전자', '보온']
# kiwi tokenizer: ['스타벅스', '체리블라', '써', 'ᆷ', '보온', '틀', '보온', '주전자', '보온병']
# article title: 록시땅 시어 바디워시&바디로션 세트
# ------------------------------------------------------------
# bpe tokenizer: ['록시땅', '시어', '바디워시', '바디로션', '세트']
# kiwi tokenizer: ['록시', '땅', '시어', '바디워', '시', '바', '로션', '세트']
# article title: 이케아 기차놀이 세트 + 전동기차 + 여분기차
# ------------------------------------------------------------
# bpe tokenizer: ['이케아', '놀이', '세트', '전동']
# kiwi tokenizer: ['이케아', '기차', '놀이', '세트', '전동기', '차', '여분', '기차']
# article title: 스팸세트 6호(12개입)
# ------------------------------------------------------------
# bpe tokenizer: ['스팸세트', '6호', '12개입']
# kiwi tokenizer: ['스팸', '세트', '호', '개입']
# article title: 벨로앤벨라 팔찌 & 반지 10종 세트 (미착용)
# ------------------------------------------------------------
# bpe tokenizer: ['벨라', '팔찌', '반지', '10종', '세트', '미착용']
# kiwi tokenizer: ['벨로앤벨', '팔찌', '반지', '종', '세트', '미', '착용']
# article title: (미개봉)(쇼핑백)CJ 현명한선택F호 선물세트(스팸,올리고당,해바라기씨유)
# ------------------------------------------------------------
# bpe tokenizer: ['미개봉', '쇼핑백', 'cj', '현명한선택', 'f호', '선물세트', '스팸', '올리고당', '해바라기씨유']
# kiwi tokenizer: ['개봉', '쇼핑백', '현명', '선택', '호', '선물', '세트', '스팸', '당', '해바라기', '씨', '유']
# article title: 한본 그래픽 타블렛 풀세트 싼 가격에 양도합니다
# ------------------------------------------------------------
# bpe tokenizer: ['그래', '블렛', '풀세트', '가격', '합니다']
# kiwi tokenizer: ['한보', '그래픽', '타블', '렛', '풀', '세트', '가격', '양도']
# article title: 이솝 핸드밤 바디클렌저 세트
# ------------------------------------------------------------
# bpe tokenizer: ['이솝', '핸드밤', '바디클렌저', '세트']
# kiwi tokenizer: ['이솝', '핸드', '밤', '바디', '클렌저', '세트']
# article title: 스토케 트립트랩 뉴본세트(거의 새것) 팝니다.
# ------------------------------------------------------------
# bpe tokenizer: ['스토케', '트립트랩', '세트', '거의', '새것', '팝니다']
# kiwi tokenizer: ['스토케', '트리', 'ᆸ', '트랩', '뉴본', '세트', '새것']
# article title: 노 와이어 브라 80A 팬티95 2셋트
# ------------------------------------------------------------
# bpe tokenizer: ['와이', '브라', '80', '팬티', '95', '셋트']
# kiwi tokenizer: ['노', '브', '팬티', '셋트']
# article title: [미개봉 새제품] CJ 백설 스팸 선물세트 (바로 선물 가능)
# ------------------------------------------------------------
# bpe tokenizer: ['미개봉', '새제품', 'cj', '백설', '스팸', '선물세트', '선물', '가능']
# kiwi tokenizer: ['개봉', '제품', '백설', '스팸', '선물', '세트', '선물', '가능']
# article title: 새제품 > 양키캔들 보티브 향초 6종 + 유리컵홀더 선물세트 (한정)
# ------------------------------------------------------------
# bpe tokenizer: ['새제품', '양키캔들', '보티브', '향초', '6종', '유리', '홀더', '선물세트', '한정']
# kiwi tokenizer: ['제품', '양키', '캔', '보티', '브', '향초', '종', '유리컵', '홀', '선물', '세트', '한정']
# article title: 레고 옥스포드 동물&키티 쿠킹
# ------------------------------------------------------------
# bpe tokenizer: ['레고', '포드', '키티']
# kiwi tokenizer: ['레고', '옥스포드', '동물', '키티', '쿠', '킹']
# article title: 설선물하세요) 청정원 선물세트 팝니다
# ------------------------------------------------------------
# bpe tokenizer: ['선물하', '세요', '청정원', '선물세트', '팝니다']
# kiwi tokenizer: ['설', '선물', '청', '정원', '선물', '세트', '파']
# article title: 캐스키드슨 핸드크림 , 립밤 선물 세트 (미개봉 새상품)
# ------------------------------------------------------------
# bpe tokenizer: ['캐스키드슨', '핸드크림', '립밤', '선물', '세트', '미개봉', '새상품']
# kiwi tokenizer: ['캐스', '키드', '핸드', '크림', '립밤', '선물', '세트', '개봉', '상품']
# article title: 가평명지산잣 선물세트. 상태 최상
# ------------------------------------------------------------
# bpe tokenizer: ['선물세트', '상태', '최상']
# kiwi tokenizer: ['가평', '명지산', '잣', '선물', '세트', '상태', '최상']
# article title: 장수거북이 금수저세트(새상품)
# ------------------------------------------------------------
# bpe tokenizer: ['거북', '수저세트', '새상품']
# kiwi tokenizer: ['장수거북', '금', '수저', '세트', '상품']
# article title: 크렘드마롱 프랑스 국민 밤잼
# ------------------------------------------------------------
# bpe tokenizer: ['프랑스']
# kiwi tokenizer: ['크렘드', '마롱', '프랑스', '국민', '밤', '잼']
# article title: 청와대 커피잔 2인조 셋트(새제품)
# ------------------------------------------------------------
# bpe tokenizer: ['청와대', '커피잔', '2인조', '셋트', '새제품']
# kiwi tokenizer: ['청와대', '커피잔', '인', '조', '셋트', '제품']
# article title: 미개봉 새상품 랑콤 선물세트 (선물가능,비닐 그대로)
# ------------------------------------------------------------
# bpe tokenizer: ['미개봉', '새상품', '랑콤', '선물세트', '선물가능', '그대로']
# kiwi tokenizer: ['개봉', '상품', '랑콤', '선물', '세트', '선물', '가능', '비닐']
# article title: 니트 롱원피스 머플러 세트
# ------------------------------------------------------------
# bpe tokenizer: ['니트', '원피스', '플러', '세트']
# kiwi tokenizer: ['니트', '롱', '원피스', '머플러', '세트']
# article title: (새 제품)타이틀리스트Pro V1x 골프공 12개세트
# ------------------------------------------------------------
# bpe tokenizer: ['제품', '타이틀', '리스', 'pro', '골프공', '12', '개세트']
# kiwi tokenizer: ['제품', '타이틀', '리스트', '골프공', '개', '세트']
# article title: 영국 포트메리온 파스타볼(백화점 정품 새상품)2개가격
# ------------------------------------------------------------
# bpe tokenizer: ['영국', '포트메리온', '스타', '백화점', '정품', '새상품', '2개', '가격']
# kiwi tokenizer: ['영국', '포트메리', '파스타', '볼', '백화점', '정품', '상품', '개', '가격']
# article title: 조말론 Jo Malone 홀로그램 한정판 홀리데이 에디션 비누 15개 세트
# ------------------------------------------------------------
# bpe tokenizer: ['조말론', 'al', 'on', '그램', '한정판', '홀리데이', '에디션', '비누', '15개', '세트']
# kiwi tokenizer: ['조말', '그램', '한정판', '홀리데이', '에디', '셔', '비누', '개', '세트']
# article title: [급처] 3ce 아이섀도우, 립스틱 선물세트 (미개봉)
# ------------------------------------------------------------
# bpe tokenizer: ['급처', '아이섀도우', '립스틱', '선물세트', '미개봉']
# kiwi tokenizer: ['ᆸ', '처', '아이섀도우', '립스틱', '선물', '세트', '개봉']
# article title: [새상품] 이솝 더 유머리스트 바디밤&바디클렌저 Aesop
# ------------------------------------------------------------
# bpe tokenizer: ['새상품', '이솝', '리스트', '바디밤', '바디클렌저', 'aesop']
# kiwi tokenizer: ['상품', '이솝', '유머', '리스트', '바디', '밤', '바디클렌', '저']
# article title: 마리슈타이거 아이스볼 메이커
# ------------------------------------------------------------
# bpe tokenizer: ['마리', '타이', '아이스', '메이커']
# kiwi tokenizer: ['마리슈타', '이거', '아이스', '볼', '메이커']
# article title: 유기농 발아 잡곡세트
# ------------------------------------------------------------
# bpe tokenizer: ['유기농', '세트']
# kiwi tokenizer: ['유기농', '발아', '잡곡', '세트']
# article title: 올가멸치선물세트2호
# ------------------------------------------------------------
# bpe tokenizer: ['멸치', '선물세트', '2호']
# kiwi tokenizer: ['올가멸치', '선물', '세트', '호']
# article title: 블루필 mini head fan pro
# ------------------------------------------------------------
# bpe tokenizer: ['블루', 'in', 'ea', 'pro']
# kiwi tokenizer: ['블루', '필']
# article title: (가격내림)[미개봉 새상품] 입생로랑 엉크르 드 뽀 매트 쿠션 파운데이션 본품 20호 & 루쥬 볼륍떼 샤인 106호
# ------------------------------------------------------------
# bpe tokenizer: ['가격내림', '미개봉', '새상품', '입생로랑', '매트', '쿠션', '파운데이션', '본품', '20호', '10', '6호']
# kiwi tokenizer: ['가격', 'ᆷ', '개봉', '상품', '입생로', '엉크', '르', '드', '매트', '쿠션', '파운데이션', '품', '호', '루쥬', '볼륍', '샤인', '호']
# article title: 로아주 목걸이 세트
# ------------------------------------------------------------
# bpe tokenizer: ['목걸이', '세트']
# kiwi tokenizer: ['로', '목걸이', '세트']
# article title: [새상품]록시땅 시어버터 핸드크림&립세트
# ------------------------------------------------------------
# bpe tokenizer: ['새상품', '록시땅', '시어버터', '핸드크림', '립세트']
# kiwi tokenizer: ['상품', '록시', '땅', '시어버터', '핸드', '크림', '립', '세트']
# article title: 포트메리온 식탁매트4개 판매합니다
# ------------------------------------------------------------
# bpe tokenizer: ['포트메리온', '식탁', '4개', '판매합니다']
# kiwi tokenizer: ['포트메리', '식탁', '매트', '개', '판매']
# article title: (미개봉)꽁빠니 드 포로방스 핸드워시 ᆞ로션
# ------------------------------------------------------------
# bpe tokenizer: ['미개봉', '핸드워시', '로션']
# kiwi tokenizer: ['개봉', '꽁빠', '드', '포로', '방', '핸드워', '시', '로션']
# article title: 샤넬 남성용 넥타이
# ------------------------------------------------------------
# bpe tokenizer: ['샤넬', '남성용', '넥타이']
# kiwi tokenizer: ['샤넬', '남성', '넥타이']
# article title: 일리 커피머신(일리 에스프레소 x7.1)
# ------------------------------------------------------------
# bpe tokenizer: ['커피머신', '에스프레소']
# kiwi tokenizer: ['일리', '커피', '머신', '일리', '에스프레소']
# article title: 4c 다이아몬드 은목걸이, 귀걸이 셋트 (새상품) 도금처리
# ------------------------------------------------------------
# bpe tokenizer: ['다이아몬드', '목걸이', '귀걸이', '셋트', '새상품']
# kiwi tokenizer: ['다이아몬드', '은', '목걸이', '귀걸이', '셋트', '상품', '도금', '처리']
# article title: 스틸라 색조화장 세트
# ------------------------------------------------------------
# bpe tokenizer: ['스틸라', '세트']
# kiwi tokenizer: ['스틸', '색조', '화장', '세트']
# article title: (새상품) 오설록 3종 티 세트 (차)
# ------------------------------------------------------------
# bpe tokenizer: ['새상품', '오설록', '3종', '세트']
# kiwi tokenizer: ['상품', '오설록', '종', '티', '세트', '차']
# article title: 새상품*파스텔톤 트위드투피스 니트트위드 고급스런룩 상견례투피스 하객룩(봄 여름 가을 트위드
# ------------------------------------------------------------
# bpe tokenizer: ['새상품', '파스', '위드', '피스', '니트', '고급', '피스', '여름']
# kiwi tokenizer: ['상품', '파스텔', '톤', '트위드', '투피스', '니트트위', '드', '고급스런', '룩', '상견례', '투피스', '하객', '룩', '봄', '여름', '가을', '트위', '드']
# article title: (새거)월데코 3종 세트
# ------------------------------------------------------------
# bpe tokenizer: ['새거', '3종', '세트']
# kiwi tokenizer: ['거', '월데', '코', '종', '세트']
# article title: (미개봉 새상품) LG 생활건강 엘라스틴 프로폴리테라 샴푸 선물 세트
# ------------------------------------------------------------
# bpe tokenizer: ['미개봉', '새상품', 'lg', '생활건강', '엘라스틴', '프로폴', '테라', '샴푸', '선물', '세트']
# kiwi tokenizer: ['개봉', '상품', '생활', '건강', '엘라스', '티', '프로폴리테', '샴푸', '선물', '세트']
# article title: 수저세트(금색,8세트)
# ------------------------------------------------------------
# bpe tokenizer: ['수저세트', '세트']
# kiwi tokenizer: ['수저', '세트', '금색', '세트']
# article title: 캐드 키드슨(Cath kidston) 컵 4종 세트(미개봉 새상품)
# ------------------------------------------------------------
# bpe tokenizer: ['키드슨', 'at', 'ki', 'st', 'on', '4종', '세트', '미개봉', '새상품']
# kiwi tokenizer: ['드', '키드', '컵', '종', '세트', '개봉', '상품']
# article title: 쯔비벨 무스터 커피잔
# ------------------------------------------------------------
# bpe tokenizer: ['쯔비', '무스터', '커피잔']
# kiwi tokenizer: ['쯔비', '벨', '무스', '터', '커피잔']
# article title: 추석 선물세트/동원참치 진호, 스팸 21호, 사랑둥이 해풀잎 D1호
# ------------------------------------------------------------
# bpe tokenizer: ['추석', '선물세트', '동원참치', '스팸', '21호', '사랑', '1호']
# kiwi tokenizer: ['추석', '선물', '세트', '동원', '참치', '진호', '스팸', '호', '사랑둥', '해', '풀잎', '호']
# article title: 신상 스와로브스키 크리스털 바나나 목걸이(미착용 새것)
# ------------------------------------------------------------
# bpe tokenizer: ['신상', '스와로브스키', '크리스', '목걸이', '미착용', '새것']
# kiwi tokenizer: ['신상', '스와로브스키', '크리스털', '바나나', '목걸이', '미', '착용', '새것']
# article title: 에뜨와 90 여아 원피스 + 부르마 세트 새상품급
# ------------------------------------------------------------
# bpe tokenizer: ['에뜨와', '90', '여아', '원피스', '르마', '세트', '새상품급']
# kiwi tokenizer: ['에뜨', '여아', '원피스', '세트', '상품', '급']
# article title: [새제품] 프리메라 오가니언스 2종세트 선물가능
# ------------------------------------------------------------
# bpe tokenizer: ['새제품', '프리메라', '오가', '언스', '2종세트', '선물가능']
# kiwi tokenizer: ['제품', '프리메', '오가니언', '종', '세트', '선물', '가능']
# article title: 오설록선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['오설', '선물세트']
# kiwi tokenizer: ['오설록', '선물', '세트']
# article title: 듀퐁 지갑 세트 명함지갑 포함
# ------------------------------------------------------------
# bpe tokenizer: ['지갑', '세트', '명함', '지갑', '포함']
# kiwi tokenizer: ['듀퐁', '지갑', '세트', '명함', '지갑', '포함']
# article title: (선물용) 매일유업 골든 밀크 - (캔2스틱1텀블러세트) 정상가62000원
# ------------------------------------------------------------
# bpe tokenizer: ['선물용', '밀크', '스틱', '텀블러', '세트', '000원']
# kiwi tokenizer: ['선물', '매일유업', '골드', '밀크', '캔2스틱1텀블러', '세트', '정상', '원']
# article title: 양키캔들 보티브 향초 3종 투명 캔들 홀더 선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['양키캔들', '보티브', '향초', '3종', '투명', '캔들', '홀더', '선물세트']
# kiwi tokenizer: ['양키', '캔', '보티', '브', '향초', '종', '투명', '캔', '홀', '선물', '세트']

# %%
compare(14317)

# 핸드케어가 잘 추출됨
# Out:
# article title: (새상품)데메테르 핸드케어 4종세트
# ------------------------------------------------------------
# bpe tokenizer: ['새상품', '테르', '핸드', '케어', '4종세트']
# kiwi tokenizer: ['상품', '데메테르', '핸드케', '종', '세트']

# %%
compare(54906)

# 로스팜이 잘 추출됨
# Out:
# article title: [추석선물세트] 롯데의성마늘프리미엄로스팜set 팝니다
# ------------------------------------------------------------
# bpe tokenizer: ['추석선물세트', '롯데', '의성', '마늘', '프리미엄', '로스팜', 'set', '팝니다']
# kiwi tokenizer: ['추석', '선물', '세트', '롯데', '성', '마늘', '프리미엄', '로스', '파', 'ᆷ', '파']

# %%
compare(4628)
# Out:
# article title: 건면 구포국수 선물세트 (10봉)
# ------------------------------------------------------------
# bpe tokenizer: ['구포', '국수', '선물세트', '10']
# kiwi tokenizer: ['건면', '구포', '국수', '선물', '세트', '봉']

# %% [markdown]
# # 토큰화 전 키워드 정리

# %% [markdown]
# ## 딕셔너리 제작을 위한 빈도수 상위 단어 추출

# %% [markdown]
# - BPE tokenizer로 결정
# - 상품 분류를 위해 선물세트, 새제품과 같은 키워드는 필요하지 않으므로 빈도 상위 단어 중에서 필요한 단어로만 딕셔너리를 제작

# %%
cv = CountVectorizer(max_features=1000, tokenizer=tokenizer)
dtm = cv.fit_transform(df.title)

wc = pd.DataFrame({'단어': cv.get_feature_names(), '빈도':dtm.sum(axis=0).flat})
wc.sort_values('빈도', ascending=True).head(20)
# Out:
#          단어  빈도
# 467     불가리  69
# 288      더블  69
# 382    명품혼합  69
# 680      올리  69
# 782      지아  69
# 643      양수  69
# 783      진액  69
# 425     반상기  69
# 791  참치선물세트  70
# 456      보리  70
# 798     청와대  70
# 883    튜나리챔  70
# 824     캐디백  70
# 580      스토  70
# 221      교환  70
# 239      기념  70
# 936     프라이  70
# 18     12개입  70
# 241      기쁨  70
# 16      12m  70

# %%
wc.to_excel('wc_1000.xlsx')

# %% [markdown]
# ## 딕셔너리 제작
# - 상품명, 브랜드 명만 추가
# - 상위 1000개 단어 (빈도 70까지)
# - 총 578개의 키워드

# %%
# 길이가 1인 것은 따로 추가함 

# 
thanks_dict = {}
thanks_dict["spam"] = ['스팸', '리챔', '스팸선물세트', '로스팜', '스팸세트', '스팸8호', '햄','스팸6호', '스팸3호', '스팸1호', '그릭슈바인','런천미트', '수제햄', '의성마늘', '스팸복합1호', '스팸선물셋트']
thanks_dict["tuna"] = ['동원', '동원참치', '참치', '동원선물세트', '사조', '참치선물세트', '동원참치선물세트', '참치캔', '행호']
thanks_dict["hand"] = ['핸드크림', '핸드', '핸드워시', '손소독제', '더프트앤도프트', '랩신', '레저렉션']
thanks_dict["nuts"] = ['견과류', '견과']
thanks_dict["dried_seafood"] = ['멸치', '광천김', '멸치선물세트']
thanks_dict["oil"] = ['카놀라유', '참기름',  '식용유', '해바라기씨유', '트러플', '들기름', '올리브유', '해바라기유', '고급유', '포도씨유', '올리브오일', '기름', '요리유', '오일세트']
thanks_dict["ginseng"] = ['정관장', '홍삼', '인삼', '홍삼정', '6년근', '다보록', '한삼인', '활기력', '한뿌리', '홍삼스틱', '홍삼원', '홍삼선물세트']
thanks_dict["mix"] = ['청정원', 'cj', '해표', 'cj제일제당', '목우촌', '백설','스팸복합', '현명한선택', 'lg', '튜나리챔', '복합', 'cj선물세트', '안심특선', '특별한선택', '롯데', '특별한', '제일제당', '오뚜기', '농협', '혼합', '현명한', '사조해표', '스팸고급유', '청정원선물세트', '복합1호', '해표선물세트', '씨제이', '풍성한']
thanks_dict["meat"] = ['육포', '한우']
thanks_dict["fruits"] = ['사과', '표고버섯', '과일', '버섯', '곶감', '배']
thanks_dict["snacks"] = ['한과', '초콜릿', '쿠키', '과자']
thanks_dict["spicy"] = ['올리고당', '천일염', '벌꿀', '미엘드', '간장', '식초']
thanks_dict["bath_thanks"] = ['lg생활건강', '아모레퍼시픽', '애경', '생활건강', '엘지생활건강', '아모레', '엘지', '생활의']

#13

gift_dict = {}
gift_dict["hygiene"] = ['마스크', '섬유유연제', '세제']
gift_dict["coffee"] = ['스타벅스', '오설록','차', '커피', '티세트', '커피잔세트', '이디야', '카누', '티백', '드립백', 'tea', '쌍계명차', '에스프레소', '할리스', '맥심', '담터', '투썸', '녹차', '티박스', '네스프레소', '아메리카노', '핸드드립', 'twg', '허브티', '꽃차', '타바론', '홍차', '차세트', '더치커피', '비니스트', '홈카페', '투썸플레이스']
gift_dict["drink"] = ['와인', '신앙촌']
gift_dict["perfume"] = ['양키캔들', '향초', '향수', '캔들', '디퓨저', '조말론', '모링가', '캔들워머', '퍼퓸', '코코도르', '필로우미스트', '방향제', '베르사체', '디퓨져', '딥디크', '아로마', '워머세트', '양키', '바디필로우', '더블유드레스룸', '우드윅', '라벤더', '딥티크', '랑방', '보티브', '자쉐이드', '자캔들', '화이트머스크']
gift_dict["cosmetics"] = ['화장품','자음생', '설화수', '미스트', '크림', '키엘', '튼살크림','프레쉬', '에센스', '헤라', '스킨', '세럼', '토너', '립스틱', '에스티로더', '스킨케어', '비오템', '쿠션', '스틸라', '브러쉬', '탬버린즈', '입생로랑', '달바', '암웨이', '수분크림', '오휘', '디올', '앰플', '꼬달리', 'fresh', '바비브라운', '아이크림', '논픽션', '자음2종', '클렌저', 'ahc', '화장품세트', '미샤', '자음', '마스크팩', '클라란스', '랑콤', '버베나', '코리아나', '틴트', '아이오페', '스크럽', '립밤세트', '베네피트', '기초', '메이크업', '케어', '팔레트', '아이섀도우', '클렌징', '빌리프', '핸드밤', '안나수이', '카밀', '선크림', '갈색병', '이니스프리', '인셀덤', '산타마리아노벨라', '크리니크', '스킨로션', 'lush', '섀도우', '와일드로즈', '프리메라', '기초세트', 'sk2', '립밥', '파운데이션', '핸드크림세트', '한율', '남성화장품', '에멀젼', '공진향', '립세트']
gift_dict["dishes"] = ['커피잔','컵', '한국도자기', '그릇', '찻잔', '머그컵', '접시', '텀블러', '행남자기', '다기세트', '도자기', '포트메리온', '찻잔세트', '그릇세트', '머그', '와인잔', '다기', '식기세트', '티팟', '코렐', '웨지우드', '식기', '광주요', '머그잔', '본차이나', '빌레로이앤보흐', '로얄알버트', '접시세트', '국그릇', '밥그릇', '로얄', '보타닉가든', '유리컵', '로얄포드', '유리잔', '락앤락', '주전자', '맥주잔', '다기셋트', '머그세트', '방짜유기', '밀양도자기', '술잔', '컵세트', '티팟세트', '세라믹', '레녹스', '덴비', '컵받침', '다도세트']
gift_dict["kitchen"] = ['냄비', '수저세트', '수저', '칼세트', '후라이팬', '젓가락', '포크', '냄비세트', '르쿠르제', '밀폐용기', '소주잔', '프라이팬', '티스푼', '커트러리', '테팔', '네오플램', '헹켈', '키친아트', '스텐', '그라인더', '휘슬러', '글라스', '은수저', '르크루제', '스테인레스', '스테인리스', 'wmf', '나이프', '실리콘', '스텐냄비', '주방', '실리트', '반찬통', '스푼', '도마', '조리도구', '글라스락']
gift_dict["man"] = ['남성', '옴므', '남성용', '남자', '포맨', '100사이즈']
gift_dict["jewel"] = ['목걸이', '귀걸이', '스와로브스키', '팔찌', '시계', '반지', '14k', '키링', '진주', '제이에스티나', '악세사리', '24k', '팔찌세트']
gift_dict["cloth"] = ['양말', '원피스', '모자', '파우치', '손수건', '워머', '수건', '가방', '우주복', '지갑', '카드지갑', '속옷', '아디다스', '내의', '잠옷', '나이키', '폴로', '상하세트', '보스턴백', '가디건', '반지갑', '랄프로렌', '상하의', '속옷세트', '팬티', '브라', '벨트', '디스커버리', '장지갑', '양말세트', '내복', '트레이닝복', '넥타이', '바지', '목도리', '드레스', '니트', '정장', '장갑', '가죽', '타올', '빅토리아시크릿', '엘르']
gift_dict["bath"] = ['록시땅', '샴푸', '립밤', '바디워시', '배쓰', '캐스키드슨', '바디', '바디샵', '바디로션', '더바디샵', '러쉬', '로션', '치약', '비누', '샤워젤', '이솝', '버츠비', '컨디셔너', '비욘드', '히말라야', '케라시스', '트리트먼트', '입욕제', '바디세트', '시어버터', '린스', '아베다', '사봉', '캐드키드슨', '바디케어', '핑크솔트', '칫솔', '바디미스트', '배쓰밤', '바디스크럽', '요아럽', 'aesop', '바디판타지', '워시', '헤어', '바디크림', '리엔', '쿤달', '바디오일', '루치펠로', '샤워볼', '바디밤', '바디클렌저', '바디용품', '샤워', '클렌징폼', '해피바스', '섹스밤', '올가', '인덜전트']
gift_dict["nutri"] = ['콜라겐', '락토핏', '비타민', '멀티', '생유산균']
gift_dict["leisure"] = ['골프공', '골프', '아이언', '골프채', '볼빅', '골프백', '캐디백', '캠핑', '애벌레', '캘러웨이', '미즈노', '아이언세트', '테일러메이드', '드라이버', '볼마커', '타이틀리스트']
gift_dict["baby"] = ['신생아', '아기', '베베', '딸랑이', '출산선물세트', '여아', '유아','아동',  '임산부', '아기옷',  '출산선물', '장난감', '배냇저고리', '손싸개', '턱받이', '베이비', '아가방', '딸랑이세트', '속싸개', '어린이', '출산', '남아', '바디수트', '바디슈트', '오가닉맘', '젖병', '키즈', '이유식', '모빌', '치발기', '발싸개', '의자', '아기띠', '배넷저고리', '뽀로로', '맘스네이처', '상하복', '유모차', '밤부베베', '한스펌킨', '아토팜', '타요', '주방놀이', '압소바', '라마즈', '에뜨와', '밍크뮤']
gift_dict["luxury"] = ['샤넬', '구찌', '몽블랑', '루이비통', '불가리', '버버리', '페라가모', '에르메스']
gift_dict["electric"] = ['키보드', '인덕션', '마우스', '무선', '블루투스', '마사지기', '기펠', 'pro', '트리오', '닌텐도', 'led', '삼성', '청소기', '바이마르', '갤럭시', '프라엘', '스위치', '로지텍', '커피머신', '드롱기']
gift_dict["coupon"] = ['기프티콘', '선물하기', '쿠폰']
gift_dict["furnishing"] = ['이케아', '전등', '인테리어', '한샘', '무드등', '테이블', '모이몰른', '우산', '모던하우스', '이불', '베개', '미니워머', '필로우']
# gift_dict["etc"] = ['쇼핑백', '미니', '스페셜', '홀더', '듀오', '모자이크', '위드오가닉', '화이트', '클래식', '고급', '블랙', '닥스', '여성', '핑크', '로즈', '유기농', '유리', '컬렉션', '오가닉', '홈세트', '디즈니', '골드', '카카오프렌즈', '크리스마스', '에디션', '한정판', '명절선물', '크리스탈', '올인원', '볼펜', '인형', '카카오', '일본', '빈티지', '다이어리', '케이스', '라이언', '어피치', '파머스', '레드', '울트라', '러블리', '오리지널', '스페셜세트', '그린', '단호', '한국', '라미', '레트로', '물걸레', '벨벳']

# 18





all_list = []
thanks_list = []
normal_list = []
for i in list(gift_dict.values()):
    for j in i:
        normal_list.append(j)
        
for i in list(thanks_dict.values()):
    for j in i:
        thanks_list.append(j)
        
all_list = thanks_list+normal_list
len(all_list)
# Out:
# 578

# %%
# 딕셔너리 안에 포함되지 않은 단어들 

not_list = []
for i in cv.get_feature_names():
    if i not in all_list:
        not_list.append(i)
print(len(not_list))
print(list(not_list))
# Out:
# 585
# ['00', '000', '000원', '00원', '0g', '0ml', '10', '100', '100ml', '100호', '10p', '10개', '10호', '11', '11호', '12', '12m', '12개', '12개입', '12종', '12호', '13', '13호', '14', '14p', '14호', '15', '15호', '16', '16호', '18', '19', '1개', '1세트', '1인', '1호', '20', '200', '200g', '200ml', '2021', '21', '21호', '22', '22호', '23', '24', '25', '250ml', '27호', '28', '2p', '2개', '2개세트', '2병', '2세트', '2인', '2인세트', '2인조', '2종', '2종세트', '2호', '30', '30ml', '30포', '36', '37', '3p', '3개', '3세트', '3종', '3종세트', '3호', '40', '4p', '4개', '4인', '4종', '4종세트', '4호', '50', '500', '500ml', '50ml', '57호', '5kg', '5ml', '5p', '5개', '5인', '5종', '5종세트', '5호', '60', '6p', '6개', '6종', '6종세트', '6호', '70', '75', '75ml', '7개', '7종', '7호', '80', '80사이즈', '8k호', '8개', '8종', '8호', '90', '9개', '9호', 'al', 'am', 'an', 'ap', 'ar', 'at', 'a호', 'bo', 'ch', 'cm', 'co', 'di', 'ea', 'ed', 'el', 'en', 'er', 'es', 'e호', 'f호', 'g×', 'g호', 'ic', 'il', 'in', 'it', 'kg', 'la', 'le', 'lo', 'ma', 'ml', 'mm', 'nh', 'n호', 'ol', 'on', 'or', 'pc', 'pcs', 'p세트', 're', 'ro', 'se', 'set', 'ss', 'st', 's호', 'us', 'vi', '❤️', '⭐️', '가격', '가격내림', '가격인하', '가능', '가득', '가든', '가위', '가져가세요', '가지', '감사', '개봉', '개세트', '개입', '거래', '거의', '거치대', '건강', '건강한', '걸이', '겨울', '고급', '고기', '고려', '골드', '골든', '공기', '교환', '구매', '구성', '국산', '그대로', '그레이', '그린', '그림', '급처', '기념', '기쁨', '기세트', '기저귀', '기프트', '기프트세트', '기획세트', '까지', '나눔', '나무', '나이', '내림', '네이', '네일', '녹스', '녹용', '놀이', '놀이세트', '다이', '다이어리', '닥스', '닥터', '담은', '더블', '데이', '데일리', '델리', '도담', '독일', '듀오', '듀오세트', '드려요', '드림', '드립', '디너', '디즈니', '뚜껑', '라이', '라이언', '라이트', '라인', '라지', '랜드', '러브', '레드', '레드라벨', '레몬', '레스', '레이', '레인', '로즈', '리미티드', '리세트', '리스', '리아', '리유저블', '리필', '마리', '마사지', '마스', '마이', '마일드', '마지막', '만년필', '만들기', '만원', '매직', '매트', '머리', '명작', '명절', '명절선물', '명절선물세트', '명품', '명품혼합', '모이스', '모자이크', '무료', '무료나눔', '미개봉', '미개봉새상품', '미개봉새제품', '미니', '미니어처', '미사용', '미착용', '밀크', '바스', '바이', '바이오', '박스', '반값', '반상기', '받침', '배송', '백화점', '버터', '베네', '베르', '베리', '베스트', '베이', '벨벳', '보드', '보리', '보습', '볼펜', '봉투', '부부', '뷰티', '브라운', '브랜드', '브리', '블랑', '블랙', '블럭', '블루', '블루독', '비비', '비스', '비아', '빈티지', '사각', '사용', '사이즈', '상자', '상태', '상품', '상하', '새거', '새것', '새상품', '새제품', '샘플', '생일', '선물', '선물가능', '선물로', '선물박스', '선물세트', '선물세트입니다', '선물세트팝니다', '선물셋트', '선물용', '선물용으로', '선물포장', '선택', '선호', '설날', '설선물', '설선물세트', '세대', '세요', '세이', '세제품', '세탁', '세트', '세트입니다', '센트', '셋트', '소금', '소서', '소스', '소품', '솔트', '쇼핑백', '쇼핑백포함', '수면', '수제', '슈퍼', '스누피', '스몰', '스와', '스위트', '스키', '스타', '스터', '스테', '스토', '스트', '스티', '스티커', '스틱', '스파', '스페셜', '스프레이', '슬리', '시그니처', '시리즈', '시아', '시어', '시크릿', '식품', '신상', '신품', '실버', '싸게', '쌍계', '아이', '아쿠아', '아트', '안심', '양수', '어피치', '에디션', '에르', '에서', '에센셜', '에스', '에어', '에이', '여름', '여성', '여성용', '여자', '여행용', '영국', '영어', '예쁜', '오가닉', '오늘', '오리', '오브', '오일', '올리', '올리브', '올인원', '와이', '완전', '용기', '용품', '우드', '울트라', '워터', '원가', '원목', '웨어', '웨이', '위드오가닉', '유기', '유기농', '유리', '유리홀더', '유통기한', '으로', '음료', '이드', '이불세트', '이상', '이스', '인형', '일괄', '일괄판매', '일본', '입니다', '있는', '있어요', '있음', '자연', '잔세트', '장미', '장식', '저렴하게', '전기', '전동', '전용', '전통', '정가', '정리', '정품', '제이', '제주', '제품', '젤리', '종합', '종합선물세트', '좋아요', '좋은', '중국', '증정', '지아', '진액', '집들이', '짜리', '차량용', '천연', '천원', '청와대', '체리', '최저가', '추가', '추석', '추석선물', '추석선물세트', '추천', '치즈', '친환경', '카드', '카카오', '카카오프렌즈', '카페', '커버', '커플', '컬러', '컬렉션', '케이', '케이스', '코스', '콜라', '크리스마스', '크리스탈', '클라', '클래식', '클럭', '클리', '키친', '키트', '타월', '타이', '타임', '탈모', '택포', '테라', '튤립', '트레이', '트레이닝', '트리', '트세트', '특선', '특호', '튼살', '파우', '파워', '파자마', '판매', '판매합니다', '판매해요', '팔아요', '팝니다', '패드', '패키지', '팩트', '퍼스트', '페어', '페이스', '포장', '포트', '포함', '풀박', '풀박스', '풀세트', '프라', '프라이', '프레', '프로', '프리', '프리미엄', '프트', '플라워', '플러스', '플레이', '피규어', '피스', '핑크', '하우스', '하이', '하트', '한국', '한정판', '할인', '합니다', '해요', '해피', '행복', '허니', '허브', '현대백화점', '호선물세트', '호세트', '홀더', '홀리데이', '홈세트', '화이트', '휴대용']

# %% [markdown]
# ## 딕셔너리 단어별 매물 수

# %%
thanks_one_line = "|".join(thanks_list)

one_line ="|".join(all_list)
one_line
# Out:
# '스팸|리챔|스팸선물세트|로스팜|스팸세트|스팸8호|햄|스팸6호|스팸3호|스팸1호|그릭슈바인|런천미트|수제햄|의성마늘|스팸복합1호|스팸선물셋트|동원|동원참치|참치|동원선물세트|사조|참치선물세트|동원참치선물세트|참치캔|행호|핸드크림|핸드|핸드워시|손소독제|더프트앤도프트|랩신|레저렉션|견과류|견과|멸치|광천김|멸치선물세트|카놀라유|참기름|식용유|해바라기씨유|트러플|들기름|올리브유|해바라기유|고급유|포도씨유|올리브오일|기름|요리유|오일세트|정관장|홍삼|인삼|홍삼정|6년근|다보록|한삼인|활기력|한뿌리|홍삼스틱|홍삼원|홍삼선물세트|청정원|cj|해표|cj제일제당|목우촌|백설|스팸복합|현명한선택|lg|튜나리챔|복합|cj선물세트|안심특선|특별한선택|롯데|특별한|제일제당|오뚜기|농협|혼합|현명한|사조해표|스팸고급유|청정원선물세트|복합1호|해표선물세트|씨제이|풍성한|육포|한우|사과|표고버섯|과일|버섯|곶감|배|한과|초콜릿|쿠키|과자|올리고당|천일염|벌꿀|미엘드|간장|식초|lg생활건강|아모레퍼시픽|애경|생활건강|엘지생활건강|아모레|엘지|생활의|마스크|섬유유연제|세제|스타벅스|오설록|차|커피|티세트|커피잔세트|이디야|카누|티백|드립백|tea|쌍계명차|에스프레소|할리스|맥심|담터|투썸|녹차|티박스|네스프레소|아메리카노|핸드드립|twg|허브티|꽃차|타바론|홍차|차세트|더치커피|비니스트|홈카페|투썸플레이스|와인|신앙촌|양키캔들|향초|향수|캔들|디퓨저|조말론|모링가|캔들워머|퍼퓸|코코도르|필로우미스트|방향제|베르사체|디퓨져|딥디크|아로마|워머세트|양키|바디필로우|더블유드레스룸|우드윅|라벤더|딥티크|랑방|보티브|자쉐이드|자캔들|화이트머스크|화장품|자음생|설화수|미스트|크림|키엘|튼살크림|프레쉬|에센스|헤라|스킨|세럼|토너|립스틱|에스티로더|스킨케어|비오템|쿠션|스틸라|브러쉬|탬버린즈|입생로랑|달바|암웨이|수분크림|오휘|디올|앰플|꼬달리|fresh|바비브라운|아이크림|논픽션|자음2종|클렌저|ahc|화장품세트|미샤|자음|마스크팩|클라란스|랑콤|버베나|코리아나|틴트|아이오페|스크럽|립밤세트|베네피트|기초|메이크업|케어|팔레트|아이섀도우|클렌징|빌리프|핸드밤|안나수이|카밀|선크림|갈색병|이니스프리|인셀덤|산타마리아노벨라|크리니크|스킨로션|lush|섀도우|와일드로즈|프리메라|기초세트|sk2|립밥|파운데이션|핸드크림세트|한율|남성화장품|에멀젼|공진향|립세트|커피잔|컵|한국도자기|그릇|찻잔|머그컵|접시|텀블러|행남자기|다기세트|도자기|포트메리온|찻잔세트|그릇세트|머그|와인잔|다기|식기세트|티팟|코렐|웨지우드|식기|광주요|머그잔|본차이나|빌레로이앤보흐|로얄알버트|접시세트|국그릇|밥그릇|로얄|보타닉가든|유리컵|로얄포드|유리잔|락앤락|주전자|맥주잔|다기셋트|머그세트|방짜유기|밀양도자기|술잔|컵세트|티팟세트|세라믹|레녹스|덴비|컵받침|다도세트|냄비|수저세트|수저|칼세트|후라이팬|젓가락|포크|냄비세트|르쿠르제|밀폐용기|소주잔|프라이팬|티스푼|커트러리|테팔|네오플램|헹켈|키친아트|스텐|그라인더|휘슬러|글라스|은수저|르크루제|스테인레스|스테인리스|wmf|나이프|실리콘|스텐냄비|주방|실리트|반찬통|스푼|도마|조리도구|글라스락|남성|옴므|남성용|남자|포맨|100사이즈|목걸이|귀걸이|스와로브스키|팔찌|시계|반지|14k|키링|진주|제이에스티나|악세사리|24k|팔찌세트|양말|원피스|모자|파우치|손수건|워머|수건|가방|우주복|지갑|카드지갑|속옷|아디다스|내의|잠옷|나이키|폴로|상하세트|보스턴백|가디건|반지갑|랄프로렌|상하의|속옷세트|팬티|브라|벨트|디스커버리|장지갑|양말세트|내복|트레이닝복|넥타이|바지|목도리|드레스|니트|정장|장갑|가죽|타올|빅토리아시크릿|엘르|록시땅|샴푸|립밤|바디워시|배쓰|캐스키드슨|바디|바디샵|바디로션|더바디샵|러쉬|로션|치약|비누|샤워젤|이솝|버츠비|컨디셔너|비욘드|히말라야|케라시스|트리트먼트|입욕제|바디세트|시어버터|린스|아베다|사봉|캐드키드슨|바디케어|핑크솔트|칫솔|바디미스트|배쓰밤|바디스크럽|요아럽|aesop|바디판타지|워시|헤어|바디크림|리엔|쿤달|바디오일|루치펠로|샤워볼|바디밤|바디클렌저|바디용품|샤워|클렌징폼|해피바스|섹스밤|올가|인덜전트|콜라겐|락토핏|비타민|멀티|생유산균|골프공|골프|아이언|골프채|볼빅|골프백|캐디백|캠핑|애벌레|캘러웨이|미즈노|아이언세트|테일러메이드|드라이버|볼마커|타이틀리스트|신생아|아기|베베|딸랑이|출산선물세트|여아|유아|아동|임산부|아기옷|출산선물|장난감|배냇저고리|손싸개|턱받이|베이비|아가방|딸랑이세트|속싸개|어린이|출산|남아|바디수트|바디슈트|오가닉맘|젖병|키즈|이유식|모빌|치발기|발싸개|의자|아기띠|배넷저고리|뽀로로|맘스네이처|상하복|유모차|밤부베베|한스펌킨|아토팜|타요|주방놀이|압소바|라마즈|에뜨와|밍크뮤|샤넬|구찌|몽블랑|루이비통|불가리|버버리|페라가모|에르메스|키보드|인덕션|마우스|무선|블루투스|마사지기|기펠|pro|트리오|닌텐도|led|삼성|청소기|바이마르|갤럭시|프라엘|스위치|로지텍|커피머신|드롱기|기프티콘|선물하기|쿠폰|이케아|전등|인테리어|한샘|무드등|테이블|모이몰른|우산|모던하우스|이불|베개|미니워머|필로우'

# %%
# 9월
septem = df[df.upload_ym == '2021-09'].reset_index(drop=False)
print("전체 매물 수:", septem.title.count())
print("-"*40)
print("명절 선물 수 :", septem[septem.title.str.contains(thanks_one_line)].title.count())
print("명절 선물 비율 :", 
      round(septem[septem.title.str.contains(thanks_one_line)].title.count() / septem.title.count() * 100, 2), "%")
print("-"*40)
print("명절+노말 리스트에 속하지 않는 매물 수 :", septem[~septem.title.str.contains(one_line)].title.count())
print("제외 매물 비율 :", round(septem[~septem.title.str.contains(one_line)].title.count() / septem.title.count() * 100, 2), "%")
# Out:
# 전체 매물 수: 20970
# ----------------------------------------
# 명절 선물 수 : 9113
# 명절 선물 비율 : 43.46 %
# ----------------------------------------
# 명절+노말 리스트에 속하지 않는 매물 수 : 3628
# 제외 매물 비율 : 17.3 %

# %%
# 6월

june = df[df.upload_ym == '2021-06'].reset_index(drop=False)
# 9월
print("전체 매물 수:", june.title.count())
print("-"*40)
print("명절 선물 수 :", june[june.title.str.contains(thanks_one_line)].title.count())
print("명절 선물 비율 :", 
      round(june[june.title.str.contains(thanks_one_line)].title.count() / june.title.count() * 100, 2), "%")
print("-"*40)
print("명절+노말 리스트에 속하지 않는 매물 수 :", june[~june.title.str.contains(one_line)].title.count())
print("제외 매물 비율 :", round(june[~june.title.str.contains(one_line)].title.count() / june.title.count() * 100, 2), "%")
# Out:
# 전체 매물 수: 3945
# ----------------------------------------
# 명절 선물 수 : 632
# 명절 선물 비율 : 16.02 %
# ----------------------------------------
# 명절+노말 리스트에 속하지 않는 매물 수 : 751
# 제외 매물 비율 : 19.04 %

# %% [markdown]
# # BPE 및 딕셔너리 적용 토큰화
# ## 토큰화 결과 비교
# - 토큰화 진행시 상품 분류에 적합하지 않는 키워드도 같이 추출되므로 이를 제외하고 딕셔너리 안에 있는 단어만 추출하는 함수를 따로 적용

# %%
# 딕셔너리 활용 
def tokenizer_in_dict(text):
    enc = bpe.encode(text)
    for token in enc.tokens:
        token = token.replace('</w>', '')
        if token in all_list:
#             if len(token) > 1:
            yield token

    
# 제품명은 걸러내는 함수 
def tokenizer_notin_dict(text):
    enc = bpe.encode(text)
    for token in enc.tokens:
        token = token.replace('</w>', '')
        if token not in all_list:
            if len(token) > 1:
                yield token
                
def compare_bpe(num):
    text = df.title[num]
    print('article title:' , text)
    print('-'*60)
    print('bpe tokenizer:', list(tokenizer(text)))
    print('bpe+dict tokenizer:', list(tokenizer_in_dict(text)))

# %%
compare_bpe(1849)   # 필요한 키워드만 추출됨
# Out:
# article title: 양키캔들 보티브 향초 3종 투명 캔들 홀더 선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['양키캔들', '보티브', '향초', '3종', '투명', '캔들', '홀더', '선물세트']
# bpe+dict tokenizer: ['양키캔들', '보티브', '향초', '캔들']

# %%
compare_bpe(62345)
# Out:
# article title: 데톨 세정비누 세트(새제품)
# ------------------------------------------------------------
# bpe tokenizer: ['세정', '비누', '세트', '새제품']
# bpe+dict tokenizer: ['비누']

# %%
compare_bpe(63923)
# Out:
# article title: (새상품) 오설록 오땡큐 티박스 선물세트
# ------------------------------------------------------------
# bpe tokenizer: ['새상품', '오설록', '땡큐', '티박스', '선물세트']
# bpe+dict tokenizer: ['오설록', '티박스']

# %% [markdown]
# ## 빈도수 상위 단어 재추출 (명절 빛 비명절 시즌 비교)

# %%
cv4 = CountVectorizer(max_features=700, tokenizer=tokenizer_in_dict)
dtm4 = cv4.fit_transform(df.title)

wc4 = pd.DataFrame({'단어': cv4.get_feature_names(), '빈도':dtm4.sum(axis=0).flat})
wc4.sort_values('빈도', ascending=False).head(30)
# Out:
#        단어    빈도
# 287    스팸  3965
# 549  핸드크림  2525
# 122   록시땅  2199
# 339  양키캔들  2115
# 87     동원  1594
# 6      cj  1396
# 430   청정원  1369
# 252    샴푸  1245
# 170    바디  1141
# 420     차  1090
# 471    크림  1037
# 131    립밤  1030
# 281  스타벅스   890
# 423    참치   856
# 564    홍삼   830
# 452    커피   804
# 89   동원참치   792
# 554    향수   788
# 198     배   781
# 181  바디워시   776
# 227    비누   758
# 312    아기   753
# 437    치약   743
# 555    향초   738
# 156   목걸이   736
# 42     그릇   725
# 571   화장품   724
# 129    리챔   708
# 454   커피잔   706
# 439  카놀라유   705

# %%
wc4.to_excel('wc_578.xlsx')

# %% [markdown]
# ### 딕셔너리안에 있는 단어로만 - 9월
# - 스팸, 참치, 핸드크림, 록시땅 등이 눈에 띈다

# %%
cv2 = CountVectorizer(max_features=700, tokenizer=tokenizer_in_dict)
dtm2 = cv2.fit_transform(septem.title)

wc2 = pd.DataFrame({'단어': cv2.get_feature_names(), '빈도':dtm2.sum(axis=0).flat})
wc2.sort_values('빈도', ascending=False).head(30)
# Out:
#          단어    빈도
# 285      스팸  1552
# 6        cj   700
# 87       동원   642
# 428     청정원   570
# 547    핸드크림   519
# 121     록시땅   408
# 197       배   340
# 562      홍삼   332
# 421      참치   319
# 89     동원참치   299
# 337    양키캔들   293
# 250      샴푸   263
# 128      리챔   260
# 469      크림   253
# 169      바디   247
# 540      해표   233
# 549       햄   228
# 437    카놀라유   226
# 293  스팸선물세트   220
# 450      커피   218
# 130      립밤   206
# 418       차   205
# 420     참기름   189
# 406     정관장   185
# 180    바디워시   177
# 569     화장품   173
# 559   현명한선택   170
# 543      핸드   168
# 435      치약   167
# 235      사과   166

# %% [markdown]
# ### 딕셔너리안에 있는 단어로만 - 6월 (비명절 시즌)

# %%
june = df[df.upload_ym == '2021-06'].reset_index(drop=False)
cv4 = CountVectorizer(max_features=700, tokenizer=tokenizer_in_dict)
dtm4 = cv4.fit_transform(june.title)

wc4 = pd.DataFrame({'단어': cv4.get_feature_names(), '빈도':dtm4.sum(axis=0).flat})
wc4.sort_values('빈도', ascending=False).head(30)
# Out:
#        단어   빈도
# 521  핸드크림  133
# 113   록시땅  131
# 317  양키캔들  118
# 160    바디   67
# 239    샴푸   65
# 395     차   59
# 445    크림   59
# 272    스팸   56
# 266  스타벅스   56
# 431     컵   55
# 146   목걸이   53
# 290    아기   52
# 171  바디워시   51
# 122    립밤   50
# 36    귀걸이   47
# 526    향초   44
# 38     그릇   44
# 214    비누   43
# 517    핸드   42
# 58     냄비   42
# 108    로션   42
# 242   설화수   41
# 421    캔들   40
# 525    향수   38
# 80    도자기   37
# 284   신생아   35
# 534    홍삼   35
# 74   더바디샵   35
# 257    수저   35
# 426    커피   34

# %% [markdown]
# ### 딕셔너리에 포함되지 않은 단어로만
# - 새상품, 미개봉, 세제품, 미사용 이라는 단어가 눈에 띈다

# %%
cv3 = CountVectorizer(max_features=700, tokenizer=tokenizer_notin_dict)
dtm3 = cv3.fit_transform(df.title)

wc3 = pd.DataFrame({'단어': cv3.get_feature_names(), '빈도':dtm3.sum(axis=0).flat})
wc3.sort_values('빈도', ascending=False).head(20)
# Out:
#          단어     빈도
# 408    선물세트  24645
# 426      세트  19765
# 398     새상품  14478
# 399     새제품   6207
# 341     미개봉   5182
# 649     팝니다   3792
# 404      선물   3129
# 646   판매합니다   2696
# 429      셋트   1798
# 648     팔아요   1534
# 411    선물셋트   1533
# 645      판매   1450
# 412     선물용   1427
# 58       2개   1386
# 346     미사용   1357
# 592      추석   1174
# 79       3종   1161
# 190    가격내림   1119
# 669    프리미엄   1096
# 594  추석선물세트   1085

# %% [markdown]
# # 토큰화 진행

# %%
df['token'] = df.title.apply(lambda x : sorted(list(set(list(tokenizer_in_dict(x))))))

# %%
df.shape
# Out:
# (84102, 16)

# %%
df_token = df[df.token.apply(len) > 0].reset_index(drop=True)

# %%
df_token.shape
# Out:
# (67421, 16)

# %%
df_token['token_sum'] = df_token.token.apply(lambda x : " ".join([i for i in x]))

# %% [markdown]
# # 카테고리 컬럼

# %%
gift_cate_list = list(gift_dict.keys())
thanks_cate_list = list(thanks_dict.keys())

def category_sort(x):
    category_list = []
    for token in x:
        for name in thanks_cate_list:
            if token in thanks_dict[name]:
                category_list.append(name)
        for name in gift_cate_list:
            if token in gift_dict[name]:
                category_list.append(name)
    return sorted(list(set(category_list)))

# %%
df_token['cate_temp'] = df_token['token'].apply(category_sort)

# %%
def category_final(x):
    if len(x) == 1:
        result = x[0]
    elif len(x) > 1:
        if 'hand' in x:
            result = 'hand'
        elif 'etc' in x:
            x.remove('etc')
            result = x[0]
        elif 'tools' in x:
            result = 'tools'
        elif ('oil' in x)\
            or ('spam' in x)\
            or ('tuna' in x):
            result = 'mix'
        elif 'man' in x:
            result = 'man'
        elif 'cosmetics' in x:
            result = 'cosmetics'
        elif 'ginseng' in x:
            result = 'ginseng'
        elif 'bath_thanks' in x:
            result = 'bath_thanks'
        elif ('coffee' in x) \
            and ('dishes' in x):
            result = 'dishes'
        elif 'kitchen' in x:
            result = 'kitchen'
        elif ('cloth' in x) \
            and ('luxury' in x):
            result = 'luxury'
        elif 'perfume' in x :
            result = 'perfume'
        else:
            result = x[0]
    return result

# %%
df_token['cate_final'] = df_token.cate_temp.apply(category_final)

# %%
df_token[(df_token.cate_temp.apply(len) > 1)][['title', 'token', 'cate_temp',  'cate_final']].sample(20)
# Out:
#                                                 title  \
# 61179                              동원 선물세트(참치8 + 리챔4)
# 34521                       모로칸오일 새제품 선물세트 헤어오일 헤어에센스
# 17230                             록시땅 핸드크림 30ml 2개 세트
# 57681                              아기 유아옷 여아원피스 90사이즈
# 29646                    한국전통 고려청자 도자기 장식용 인테리어 소품 01
# 35759                     새상품(세탁만 함) 카터스 아기옷 12m + 모자
# 9851                                   스팸식용유올리고당 선물세트
# 51582                 (미개봉새상품) 기펠 엘리시아 회전조리도구 10,000원
# 37612                                    동원 참치,햄 선물셋트
# 45181               록시땅 시어버터 핸드크림 + 립밤 듀오 세트 (선물 포장)
# 61643                            록시땅선물세트 바디&비누&미니핸드크림
# 7993                              버츠비 립밥 3개 세트 + 틴케이스
# 42458  (새상품) 끌로에 향수 / 오드퍼퓸 스프레이 75ml & 바디 100ml 선물 세트
# 462                                출산선물(니트턱받이,양말) 새상품
# 38378                    록시땅 버베나 샤워젤+ 쿨링 핸드 크림 젤 + 박스
# 8078                               백설 식용유 선물세트 판매합니다.
# 58682                [스타벅스] 리유저블 텀블러+ VIA 커피 선물세트 새상품
# 27113                비오템 옴므 포스 수프림 모이스처라이저&세럼 미개봉 새상품
# 31951                        롯데 로스팜 16개 추석 선물 세트 스팸세트
# 23344                                  cj 스팸 선물세트 JH호
#
#                          token                cate_temp cate_final
# 61179             [동원, 리챔, 참치]             [spam, tuna]        mix
# 34521                [에센스, 헤어]        [bath, cosmetics]  cosmetics
# 17230              [록시땅, 핸드크림]             [bath, hand]       hand
# 57681        [아기, 여아, 원피스, 유아]            [baby, cloth]       baby
# 29646              [도자기, 인테리어]     [dishes, furnishing]     dishes
# 35759                [모자, 아기옷]            [baby, cloth]       baby
# 9851           [스팸, 식용유, 올리고당]       [oil, spam, spicy]        mix
# 51582               [기펠, 조리도구]      [electric, kitchen]    kitchen
# 37612              [동원, 참치, 햄]             [spam, tuna]        mix
# 45181    [록시땅, 립밤, 시어버터, 핸드크림]             [bath, hand]       hand
# 61643      [록시땅, 바디, 비누, 핸드크림]             [bath, hand]       hand
# 7993                 [립밥, 버츠비]        [bath, cosmetics]  cosmetics
# 42458                 [바디, 향수]          [bath, perfume]    perfume
# 462        [니트, 양말, 출산선물, 턱받이]            [baby, cloth]       baby
# 38378  [록시땅, 버베나, 샤워젤, 크림, 핸드]  [bath, cosmetics, hand]       hand
# 8078                 [백설, 식용유]               [mix, oil]        mix
# 58682          [스타벅스, 커피, 텀블러]         [coffee, dishes]     dishes
# 27113            [비오템, 세럼, 옴므]         [cosmetics, man]        man
# 31951          [로스팜, 롯데, 스팸세트]              [mix, spam]        mix
# 23344                 [cj, 스팸]              [mix, spam]        mix

# %%
df_token.groupby(['region_gu','cate_final', ]).title.count()
# Out:
# region_gu  cate_final
# 강남구        baby           252
#            bath           337
#            bath_thanks     52
#            cloth          236
#            coffee         249
#                          ...
# 중랑구        perfume        134
#            snacks           9
#            spam           153
#            spicy           11
#            tuna            52
# Name: title, Length: 800, dtype: int64

# %%
df_token[df_token.cate_final == 'fruits'][['title', 'token', 'cate_temp', 'cate_final']].sample(40)
# Out:
#                                             title        token      cate_temp  \
# 12598  썬플러스 사과 선물세트 5kg(15과/선물포장) 추석 선물 세트 일요일까지만         [사과]       [fruits]
# 17797                              사과선물세트 5kg 16과         [사과]       [fruits]
# 29187                          추석선물세트 7.5kg 배 특등급          [배]       [fruits]
# 32122                                      🍄송화버섯🍄         [버섯]       [fruits]
# 48752                              디바총\코스프레\보조배터리          [배]       [fruits]
# 61609                                     사과 선물세트         [사과]       [fruits]
# 57912                               참송고 추재버섯 선물세트         [버섯]       [fruits]
# 32326                                 사과 선물세트 팝니다         [사과]       [fruits]
# 40384                                       배선물세트          [배]       [fruits]
# 8141                                        선물용과일         [과일]       [fruits]
# 43747                          나주배 추석 과일 선물세트 팝니다      [과일, 배]       [fruits]
# 46014                                    나주배 선물세트          [배]       [fruits]
# 5808                   명품배선물세트 특특상품 7.5kg 당도12%이상          [배]       [fruits]
# 58296                                      배 선물세트          [배]       [fruits]
# 7895                             농협 저탄소 명품 배 선물세트      [농협, 배]  [fruits, mix]
# 52789                                  카페베네 과일청세트         [과일]       [fruits]
# 55636                   가격내림 )설날 배세트 ( 설날 선물 강추!@          [배]       [fruits]
# 58778               뜨라네 프리미엄 배 추석 선물세트 10개  7.5kg          [배]       [fruits]
# 4305                                   추석선물 배입니다.          [배]       [fruits]
# 49557                                     사과 선물세트         [사과]       [fruits]
# 53921                          새상품-버섯3종 선물세트(설선물)         [버섯]       [fruits]
# 50582                                   추석선물세트 버섯         [버섯]       [fruits]
# 54183                     새상품 파자마(옵션변경가능,집으로직접배달)          [배]       [fruits]
# 31969    [설선물세트]오가닉 유기농 표고버섯혼합 나눔세트/신세계 정품/오늘 받아옴     [버섯, 혼합]  [fruits, mix]
# 38773                     버섯 선물세트(정성담은 명품백화고혼합세트)         [버섯]       [fruits]
# 57850            미개봉품) 위블리즈 배를품은도라지스틱 30포세트(선물가능)          [배]       [fruits]
# 43091                           사과 11과 5kg 추석선물세트         [사과]       [fruits]
# 15399                     프리미엄 엔비사과 1박스 (2kg, 9개)         [사과]       [fruits]
# 5349                       사과 8개(선물세트) 팝니다(흠집5개더)         [사과]       [fruits]
# 29577                                   배 추석 선물세트          [배]       [fruits]
# 33774                   피코크 고당도 배 9개 과일 명절선물세트 반값      [과일, 배]       [fruits]
# 23156                           선물세트 과일 배 10개 팝니다      [과일, 배]       [fruits]
# 3319                                    송고버섯 선물세트         [버섯]       [fruits]
# 65195                              베이블레이드 갓 배틀 세트          [배]       [fruits]
# 59303                             추석 사과 선물세트 팝니다!         [사과]       [fruits]
# 7236                          보조배터리 5000mAh(새 상품)          [배]       [fruits]
# 52960                                    배민 문구 세트          [배]       [fruits]
# 32607                  (설선물)'초록마을' 사과배 8만원짜리 선물세트      [배, 사과]       [fruits]
# 52770                             명품 과일(사과,배)판매해요  [과일, 배, 사과]       [fruits]
# 1114                                       배 선물세트          [배]       [fruits]
#
#       cate_final
# 12598     fruits
# 17797     fruits
# 29187     fruits
# 32122     fruits
# 48752     fruits
# 61609     fruits
# 57912     fruits
# 32326     fruits
# 40384     fruits
# 8141      fruits
# 43747     fruits
# 46014     fruits
# 5808      fruits
# 58296     fruits
# 7895      fruits
# 52789     fruits
# 55636     fruits
# 58778     fruits
# 4305      fruits
# 49557     fruits
# 53921     fruits
# 50582     fruits
# 54183     fruits
# 31969     fruits
# 38773     fruits
# 57850     fruits
# 43091     fruits
# 15399     fruits
# 5349      fruits
# 29577     fruits
# 33774     fruits
# 23156     fruits
# 3319      fruits
# 65195     fruits
# 59303     fruits
# 7236      fruits
# 52960     fruits
# 32607     fruits
# 52770     fruits
# 1114      fruits

# %%
df_token.to_excel('df_token_2.xlsx', index=False)
