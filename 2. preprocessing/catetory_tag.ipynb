# %%
import pandas as pd

# %%
df = pd.read_excel('gift_set_dict.xlsx')

# %%
df.head()
# Out:
#         spam       tuna        hand    nuts dried_seafood        oil ginseng  \
# 0      '스팸',      '동원',     '핸드크림',  '견과류',         '멸치',    '카놀라유',  '정관장',
# 1      '리챔',    '동원참치',       '핸드',   '견과',        '광천김',     '참기름',   '홍삼',
# 2  '스팸선물세트',      '참치',     '핸드워시',     NaN     '멸치선물세트',      '오일',  '홍삼정',
# 3     '로스팜',  '동원선물세트',     '손소독제',     NaN           NaN      식용유',  '6년근',
# 4    '스팸세트',      '사조',  '더프트앤도프트',     NaN           NaN  '해바라기씨유',  '다보록',
#
#          mix   meat   fruits  ...   cloth      bath    nutri leisure  \
# 0     '청정원',  '육포',    '사과',  ...   '양말',    '록시땅',   '콜라겐',  '골프공',
# 1      'cj',  '한우',  '표고버섯',  ...   '모자',     '샴푸',   '락토핏',   '골프',
# 2      '해표',    NaN    '과일',  ...  '파우치',     '립밤',   '비타민',  '아이언',
# 3  'cj제일제당',    NaN    '버섯',  ...  '손수건',   '바디워시',    '멀티',  '골프채',
# 4     '목우촌',    NaN      NaN  ...   '워머',  '캐스키드슨',  '생유산균',   '볼빅',
#
#         baby   luxury electric   coupon furnishing     etc
# ...

# %%
for column in list(df.columns):
    df[column] = df[column].str.extract(r'(\w+)')

# %%
new_dict_list = []

for column in list(df.columns):
    temp = []
    for i in df[column].to_list():
        if str(i) != 'nan':
            temp.append(i)
            new_dict_list.append(i)
    print(f'["{column}"]', '=', temp)

new_dict_list
# Out:
# ["spam"] = ['스팸', '리챔', '스팸선물세트', '로스팜', '스팸세트', '스팸8호', '스팸6호', '스팸3호', '스팸1호', '그릭슈바인', '수제햄', '의성마늘', '스팸복합1호', '스팸선물셋트']
# ["tuna"] = ['동원', '동원참치', '참치', '동원선물세트', '사조', '참치선물세트', '동원참치선물세트', '참치캔', '행호']
# ["hand"] = ['핸드크림', '핸드', '핸드워시', '손소독제', '더프트앤도프트', '랩신', '레저렉션']
# ["nuts"] = ['견과류', '견과']
# ["dried_seafood"] = ['멸치', '광천김', '멸치선물세트']
# ["oil"] = ['카놀라유', '참기름', '오일', '식용유', '해바라기씨유', '트러플', '들기름', '올리브유', '해바라기유', '고급유', '포도씨유', '올리브오일', '기름', '요리유', '오일세트']
# ["ginseng"] = ['정관장', '홍삼', '홍삼정', '6년근', '다보록', '한삼인', '활기력', '한뿌리', '홍삼스틱', '홍삼원', '홍삼선물세트']
# ["mix"] = ['청정원', 'cj', '해표', 'cj제일제당', '목우촌', '백설', '현명한선택', 'lg', '복합', 'cj선물세트', '롯데', '특별한', '제일제당', '오뚜기', '농협', '혼합', '현명한', '사조해표', '스팸고급유', '청정원선물세트', '복합1호', '해표선물세트', '씨제이', '풍성한']
# ["meat"] = ['육포', '한우']
# ["fruits"] = ['사과', '표고버섯', '과일', '버섯']
# ["snacks"] = ['한과', '초콜릿', '쿠키']
# ["spicy"] = ['올리고당', '천일염', '벌꿀', '미엘드', '간장', '식초']
# ...

# %%
["spam"] = ['스팸', '리챔', '스팸선물세트', '로스팜', '스팸세트', '스팸8호', '햄','스팸6호', '스팸3호', '스팸1호', '그릭슈바인','런천미트', '수제햄', '의성마늘', '스팸복합1호', '스팸선물셋트']
["tuna"] = ['동원', '동원참치', '참치', '동원선물세트', '사조', '참치선물세트', '동원참치선물세트', '참치캔', '행호']
["hand"] = ['핸드크림', '핸드', '핸드워시', '손소독제', '더프트앤도프트', '랩신', '레저렉션']
["nuts"] = ['견과류', '견과']
["dried_seafood"] = ['멸치', '광천김', '멸치선물세트']
["oil"] = ['카놀라유', '참기름', '오일', '식용유', '해바라기씨유', '트러플', '들기름', '올리브유', '해바라기유', '고급유', '포도씨유', '올리브오일', '기름', '요리유', '오일세트']
["ginseng"] = ['정관장', '홍삼', '인삼', '홍삼정', '6년근', '다보록', '한삼인', '활기력', '한뿌리', '홍삼스틱', '홍삼원', '홍삼선물세트']
["mix"] = ['청정원', 'cj', '해표', 'cj제일제당', '목우촌', '백설','스팸복합', '현명한선택', 'lg', '튜나리챔', '복합', 'cj선물세트', '안심특선', '특별한선택', '롯데', '특별한', '제일제당', '오뚜기', '농협', '혼합', '현명한', '사조해표', '스팸고급유', '청정원선물세트', '복합1호', '해표선물세트', '씨제이', '풍성한']
["meat"] = ['육포', '한우']
["fruits"] = ['사과', '표고버섯', '과일', '버섯', '곶감', '배']
["snacks"] = ['한과', '초콜릿', '쿠키', '과자']
["spicy"] = ['올리고당', '천일염', '벌꿀', '미엘드', '간장', '식초']
["bath_thanks"] = ['lg생활건강', '아모레퍼시픽', '애경', '생활건강', '엘지생활건강', '아모레', '엘지', '생활의']
["hygiene"] = ['마스크', '섬유유연제', '세제']
["coffee"] = ['스타벅스', '오설록','차', '커피', '티세트', '커피잔세트', '이디야', '카누', '티백', '드립백', 'tea', '쌍계명차', '에스프레소', '할리스', '맥심', '담터', '투썸', '녹차', '티박스', '네스프레소', '아메리카노', '핸드드립', 'twg', '허브티', '꽃차', '타바론', '홍차', '차세트', '더치커피', '비니스트', '홈카페', '투썸플레이스']
["drink"] = ['와인', '신앙촌']
["perfume"] = ['양키캔들', '향초', '향수', '캔들', '디퓨저', '조말론', '모링가', '캔들워머', '퍼퓸', '코코도르', '필로우미스트', '방향제', '베르사체', '디퓨져', '딥디크', '아로마', '워머세트', '양키', '바디필로우', '더블유드레스룸', '우드윅', '라벤더', '딥티크', '랑방', '보티브', '자쉐이드', '자캔들', '화이트머스크']
["bath"] = ['록시땅', '샴푸', '립밤', '바디워시', '배쓰', '캐스키드슨', '바디', '바디샵', '바디로션', '더바디샵', '러쉬', '로션', '치약', '비누', '샤워젤', '이솝', '버츠비', '컨디셔너', '비욘드', '히말라야', '케라시스', '트리트먼트', '입욕제', '바디세트', '시어버터', '린스', '아베다', '사봉', '캐드키드슨', '바디케어', '핑크솔트', '칫솔', '바디미스트', '배쓰밤', '바디스크럽', '요아럽', 'aesop', '바디판타지', '워시', '헤어', '바디크림', '리엔', '쿤달', '바디오일', '루치펠로', '샤워볼', '바디밤', '바디클렌저', '바디용품', '샤워', '클렌징폼', '해피바스', '섹스밤', '올가', '인덜전트']
["nutri"] = ['콜라겐', '락토핏', '비타민', '멀티', '생유산균']
["leisure"] = ['골프공', '골프', '아이언', '골프채', '볼빅', '골프백', '캐디백', '캠핑', '애벌레', '캘러웨이', '미즈노', '아이언세트', '테일러메이드', '드라이버', '볼마커', '타이틀리스트']
["baby"] = ['신생아', '아기', '베베', '딸랑이', '출산선물세트', '여아', '유아','아동',  '임산부', '아기옷', '튼살크림', '출산선물', '장난감', '배냇저고리', '손싸개', '턱받이', '베이비', '아가방', '딸랑이세트', '속싸개', '어린이', '출산', '남아', '바디수트', '바디슈트', '오가닉맘', '젖병', '키즈', '이유식', '모빌', '치발기', '발싸개', '의자', '아기띠', '배넷저고리', '뽀로로', '맘스네이처', '상하복', '유모차', '밤부베베', '한스펌킨', '아토팜', '타요', '주방놀이', '압소바', '라마즈', '에뜨와', '밍크뮤']
["luxury"] = ['샤넬', '명품', '구찌', '몽블랑', '루이비통', '불가리', '버버리', '페라가모', '에르메스']
["electric"] = ['키보드', '인덕션', '마우스', '무선', '블루투스', '마사지기', '기펠', 'pro', '트리오', '닌텐도', 'led', '삼성', '청소기', '바이마르', '갤럭시', '프라엘', '스위치', '로지텍', '커피머신', '드롱기']
["coupon"] = ['기프티콘', '선물하기', '쿠폰']
["furnishing"] = ['이케아', '전등', '인테리어', '한샘', '무드등', '테이블', '모이몰른', '우산', '모던하우스', '이불', '베개', '미니워머', '필로우']
["etc"] = ['쇼핑백', '미니', '스페셜', '홀더', '듀오', '모자이크', '위드오가닉', '화이트', '클래식', '고급', '블랙', '닥스', '여성', '핑크', '로즈', '유기농', '유리', '컬렉션', '오가닉', '홈세트', '디즈니', '골드', '카카오프렌즈', '크리스마스', '에디션', '한정판', '명절선물', '크리스탈', '올인원', '볼펜', '인형', '카카오', '일본', '빈티지', '다이어리', '케이스', '라이언', '어피치', '파머스', '레드', '울트라', '러블리', '오리지널', '스페셜세트', '그린', '단호', '한국', '라미', '레트로', '물걸레', '벨벳']
